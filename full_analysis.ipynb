# %%
# %%

# =============================================================================
# MEDIA BIAS NETWORK ANALYSIS - TEMPORAL
# Research Questions:
# 1. How stable is community detection across different methodologies?
# 2. Can we derive a "true clustering" from consensus results?
# =============================================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster, leaves_list
from scipy.spatial.distance import squareform
from sklearn.metrics import silhouette_score
import networkx as nx
from collections import defaultdict, Counter
import warnings
import os
import pickle
from matplotlib.colors import LinearSegmentedColormap
warnings.filterwarnings('ignore')

from src.experiment import ExperimentFramework
from src.viz import Visualizer, COLORS, HEATMAP_CMAP, DIVERGING_CMAP, CATEGORICAL_COLORS
# Note: The analysis module has been refactored into specialized components while maintaining backward compatibility
# All existing method calls will continue to work unchanged

# %%
# %%

# =============================================================================
# 1. EXPERIMENT SETUP & DATA OVERVIEW
# =============================================================================

print("=== MEDIA BIAS NETWORK ANALYSIS ===")

# experiment parameters (temporal sampling)
data_dir = 'data/daily_cluster_matrices_min_6'
# consecutive window configuration
window_size = 15  # days per window
step_size = 15    # non-overlapping windows; set < window_size for sliding windows

results_file = f'results/temporal_experiment_{window_size}win_{step_size}step.pkl'

# -----------------------------------------------------------------------------
# 1A. LOAD EXISTING TEMPORAL EXPERIMENT RESULTS IF AVAILABLE
# -----------------------------------------------------------------------------

if os.path.exists(results_file):
    print(f"Loading existing results from {results_file}...")
    
    # load saved results
    with open(results_file, 'rb') as f:
        saved_data = pickle.load(f)
    
    temporal_summary = saved_data['experiment_summary']  # kept key name for backward compat
    analyzer = saved_data['experiment'].analyzer
    viz = Visualizer(analyzer)
    
    # NEW: Access to specialized analyzers (optional - existing code continues to work)
    # analyzer.stability_analyzer    # For stability and robustness analysis
    # analyzer.statistics_analyzer   # For significance testing and null distributions 
    # analyzer.clustering_analyzer   # For hierarchical clustering and consensus building
    # analyzer.temporal_analyzer     # For time-series and drift analysis
    
    print(f"Loaded experiment results:")
    print(f"Total results: {len(analyzer.get_results())}")
    print(f"Network methods: {len(analyzer.get_results()['network_method'].unique())}")
    print(f"Community methods: {len(analyzer.get_results()['community_method'].unique())}")
    
    # show brief summary (already computed when results were generated originally)
    print(f"\\nTEMPORAL EXPERIMENT SUMMARY (loaded):")
    print(f"Windows processed: {temporal_summary['n_windows']} (size={window_size}, step={step_size})")
    print(f"Total results: {len(analyzer.get_results())}")
    print(f"Network methods: {len(analyzer.get_results()['network_method'].unique())}")
    print(f"Community methods: {len(analyzer.get_results()['community_method'].unique())}")
    print(f"Average time per window: {temporal_summary['total_time']/max(temporal_summary['n_windows'],1):.1f}s")

else:
    print("No existing results found. Running temporal experiment...")
    print("Initializing experiment framework...")

    experiment = ExperimentFramework(data_dir)

    temporal_summary = experiment.run_temporal_experiment(window_size=window_size, step=step_size)

    analyzer = experiment.analyzer
    viz = Visualizer(analyzer)
    
    # NEW: Access to specialized analyzers (optional - existing code continues to work)
    # analyzer.stability_analyzer    # For stability and robustness analysis
    # analyzer.statistics_analyzer   # For significance testing and null distributions 
    # analyzer.clustering_analyzer   # For hierarchical clustering and consensus building
    # analyzer.temporal_analyzer     # For time-series and drift analysis

    print(f"\\nTEMPORAL EXPERIMENT SUMMARY:")
    print(f"Windows processed: {temporal_summary['n_windows']} (size={window_size}, step={step_size})")
    print(f"Total results: {len(analyzer.get_results())}")
    print(f"Network methods: {len(analyzer.get_results()['network_method'].unique())}")
    print(f"Community methods: {len(analyzer.get_results()['community_method'].unique())}")
    print(f"Average time per window: {temporal_summary['total_time']/temporal_summary['n_windows']:.1f}s")

    # save results
    print(f"\\nSaving results to {results_file}...")
    os.makedirs('results', exist_ok=True)

    save_data = {
        'experiment': experiment,
        'experiment_summary': temporal_summary,
        'window_size': window_size,
        'step_size': step_size,
        'data_dir': data_dir
    }

    with open(results_file, 'wb') as f:
        pickle.dump(save_data, f)

    print("Results saved successfully!")
# Out:
# === MEDIA BIAS NETWORK ANALYSIS ===
# Loading existing results from results/temporal_experiment_15win_15step.pkl...
# Loaded experiment results:
# Total results: 8336
# Network methods: 9
# Community methods: 10
# \nTEMPORAL EXPERIMENT SUMMARY (loaded):
# Windows processed: 16 (size=15, step=15)
# Total results: 8336
# Network methods: 9
# Community methods: 10
# Average time per window: 3.2s

# %%
# %%

# =============================================================================
# 1.1. METHOD STABILITY RANKING (variance in k across samples)
# =============================================================================

print("\\n=== METHOD STABILITY RANKING ===")

# visualize top-N most stable method combinations (low variance in k)
viz.plot_stability_ranking(top_n=15)

# fetch stability dataframe for further inspection
stability_df_overall = analyzer.analyze_stability()
if not stability_df_overall.empty:
    # pick the single most stable combination
    best = stability_df_overall.iloc[0]
    best_net = best['network_method']
    best_comm = best['community_method']
    best_param = best['param_id']

    consistency = analyzer.method_consistency(
        network_method=best_net,
        community_method=best_comm,
        param_id=best_param,
        metric='ari'
    )

    print("\\nMost stable method combination across samples:")
    print(f"  network method : {best_net}")
    print(f"  community method: {best_comm}")
    print(f"  param id        : {best_param}")
    if 'error' not in consistency:
        print(f"  mean consistency (ARI): {consistency['mean_consistency']}")
        print(f"  std  consistency      : {consistency['std_consistency']}")
        print(f"  comparisons           : {consistency['n_comparisons']}")
    else:
        # fallback message if consistency couldn't be computed (e.g., only one sample)
        print(f"  consistency analysis unavailable: {consistency['error']}")
else:
    print("Stability dataframe is empty – skipping consistency check")
# Out:
# \n=== METHOD STABILITY RANKING ===
# Top 15 Most Stable Methods:
#  1. dice + spectral_clustering: 1.000
#  2. cosine + threshold_components: 1.000
#  3. cosine + walktrap: 1.000
#  4. cosine + walktrap: 1.000
#  5. cosine + walktrap: 1.000
#  6. cosine + threshold_components: 1.000
#  7. cosine + threshold_components: 1.000
#  8. cosine + threshold_components: 1.000
#  9. cosine + threshold_components: 1.000
# 10. cosine + spectral_clustering: 1.000
# 11. pmi + k_cores: 1.000
# 12. cosine + spectral_clustering: 1.000
# 13. cosine + spectral_clustering: 1.000
# 14. cosine + spectral_clustering: 1.000
# 15. cosine + spectral_clustering: 1.000
# \nMost stable method combination across samples:
#   network method : dice
#   community method: spectral_clustering
#   param id        : params_2
#   mean consistency (ARI): 0.297
#   std  consistency      : 0.193
#   comparisons           : 120

# %%
# %%

# =============================================================================
# 1.2. TEMPORAL ROBUSTNESS ANALYSIS (stability across windows)
# =============================================================================

print("\\n=== TEMPORAL ROBUSTNESS ANALYSIS ===")

window_ids = [ws['window_id'] for ws in temporal_summary['window_summaries']]

# compute stability matrix (ARI between window clusterings)
stability_df = analyzer.temporal_stability(window_ids, metric='ari')

if not stability_df.empty:
    plt.figure(figsize=(8, 6))
    sns.heatmap(stability_df, annot=True, fmt='.2f', cmap=DIVERGING_CMAP, square=True,
                cbar_kws={'label': 'Adjusted Rand Index'})
    plt.title(f'Temporal Stability between {window_size}-Day Windows\\n(metric: ARI)', fontweight='bold')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    os.makedirs('results', exist_ok=True)
    plt.savefig('results/temporal_stability_ari.png', dpi=300, bbox_inches='tight')
    plt.show()

    print("\\nTemporal stability (ARI) summary:")
    off_diag = stability_df.values[~np.eye(len(stability_df), dtype=bool)]
    print(f"  Mean ARI: {off_diag.mean():.3f}")
    print(f"  Std  ARI: {off_diag.std():.3f}")
    print(f"  Min  ARI: {off_diag.min():.3f}")
    print(f"  Max  ARI: {off_diag.max():.3f}")
else:
    print("Stability matrix could not be computed (insufficient data)")

# =============================================================================
# 1.3. ADJACENT WINDOW DRIFT ANALYSIS
# =============================================================================
if not stability_df.empty and len(stability_df) > 1:
    consecutive_ari = [stability_df.iloc[i, i + 1]
                       for i in range(len(stability_df) - 1)]
    plt.figure(figsize=(8, 4))
    plt.plot(range(1, len(consecutive_ari) + 1),
             consecutive_ari, marker='o',
             color=COLORS['primary'], linewidth=2)
    plt.ylim(0, 1)
    plt.xlabel('window index (t → t+1)')
    plt.ylabel('adjusted rand index')
    plt.title(f'consecutive-window drift '
              f'(window={window_size}d, step={step_size}d)',
              fontweight='bold')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('results/temporal_drift_ari.png',
                dpi=300, bbox_inches='tight')
    plt.show()

    print("\\nConsecutive-window drift:")
    print(f"  mean ARI: {np.mean(consecutive_ari):.3f}")
    print(f"  std  ARI: {np.std(consecutive_ari):.3f}")

    # --- trend analysis across windows ---
    trend_res = analyzer.analyze_window_stability_trends(window_ids)
    if isinstance(trend_res, dict) and 'stability_stats' in trend_res:
        tstats = trend_res['stability_stats']
        print(f"  Temporal trend: slope = {tstats['trend_slope']:.3f} ({tstats['trend_direction']})")
        print(f"  Stability range: {tstats['min_stability']:.3f} – {tstats['max_stability']:.3f}")
else:
    print("Consecutive-window drift not computed (need ≥2 windows)")

# =============================================================================
# 1.4. LAG SIMILARITY PROFILE
# =============================================================================
if not stability_df.empty and len(stability_df) > 2:
    max_lag = min(6, len(stability_df) - 1)  # keep plot compact
    lag_means = []
    for lag in range(1, max_lag + 1):
        vals = [stability_df.iloc[i, i + lag]
                for i in range(len(stability_df) - lag)]
        lag_means.append(np.mean(vals))

    plt.figure(figsize=(6, 4))
    plt.bar(range(1, max_lag + 1), lag_means,
            color=COLORS['secondary'], alpha=0.8)
    plt.ylim(0, 1)
    plt.xlabel('lag (windows apart)')
    plt.ylabel('mean ARI')
    plt.title('time-lag similarity profile', fontweight='bold')
    plt.tight_layout()
    plt.savefig('results/temporal_lag_profile.png',
                dpi=300, bbox_inches='tight')
    plt.show()

    print("\\nLag similarity profile:")
    for lag, val in enumerate(lag_means, 1):
        print(f"  lag {lag}: mean ARI = {val:.3f}")
else:
    print("Lag similarity profile not computed (need ≥3 windows)")
# Out:
# \n=== TEMPORAL ROBUSTNESS ANALYSIS ===
# processing 521 clusterings for 49 outlets (win_00)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_00) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 131198.18
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.40
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 2766 clusters
#   Size 2: 228 clusters
#   Size 3: 139 clusters
#   Size 4: 117 clusters
#   Size 5: 119 clusters
#   Size 6: 95 clusters
#   Size 7: 68 clusters
#   Size 8: 64 clusters
#   Size 9: 80 clusters
#   Size 10: 63 clusters
#   Size 11: 70 clusters
#   Size 12: 50 clusters
#   Size 13: 47 clusters
#   Size 14: 36 clusters
#   Size 15: 22 clusters
#   Size 16: 12 clusters
#   Size 17: 15 clusters
#   Size 18: 9 clusters
#   Size 19: 15 clusters
#   Size 20: 16 clusters
#   Size 21: 10 clusters
#   Size 22: 6 clusters
#   Size 23: 7 clusters
#   Size 24: 6 clusters
#   Size 25: 9 clusters
#   Size 26: 5 clusters
#   Size 27: 15 clusters
#   Size 28: 12 clusters
#   Size 29: 6 clusters
#   Size 30: 9 clusters
#   Size 31: 5 clusters
#   Size 32: 11 clusters
#   Size 33: 18 clusters
#   Size 34: 4 clusters
#   Size 35: 3 clusters
#   Size 36: 7 clusters
#   Size 37: 4 clusters
#   Size 38: 3 clusters
#   Size 39: 5 clusters
#   Size 40: 6 clusters
#   Size 41: 3 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 45: 16 clusters
#   Size 46: 11 clusters
#   Size 47: 1 clusters
#   Size 48: 31 clusters
#   Size 49: 129 clusters
# Missing outlet warnings: 3456
# \n=== FINAL RESULTS (win_00) ===
# Mean weighted frequency: 0.214
# Max weighted frequency: 1.110
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_01)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_01) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 137573.00
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.43
# Median surprisal weight: 0.00
# Cluster size distribution:
#   Size 1: 2639 clusters
#   Size 2: 162 clusters
#   Size 3: 106 clusters
#   Size 4: 132 clusters
#   Size 5: 147 clusters
#   Size 6: 99 clusters
#   Size 7: 66 clusters
#   Size 8: 52 clusters
#   Size 9: 50 clusters
#   Size 10: 112 clusters
#   Size 11: 64 clusters
#   Size 12: 64 clusters
#   Size 13: 29 clusters
#   Size 14: 16 clusters
#   Size 15: 14 clusters
#   Size 16: 27 clusters
#   Size 17: 32 clusters
#   Size 18: 12 clusters
#   Size 19: 5 clusters
#   Size 20: 15 clusters
#   Size 21: 11 clusters
#   Size 22: 24 clusters
#   Size 23: 14 clusters
#   Size 24: 12 clusters
#   Size 25: 16 clusters
#   Size 26: 27 clusters
#   Size 27: 8 clusters
#   Size 28: 10 clusters
#   Size 29: 11 clusters
#   Size 30: 8 clusters
#   Size 31: 5 clusters
#   Size 32: 7 clusters
#   Size 33: 3 clusters
#   Size 34: 2 clusters
#   Size 35: 2 clusters
#   Size 36: 1 clusters
#   Size 37: 4 clusters
#   Size 38: 5 clusters
#   Size 39: 11 clusters
#   Size 40: 2 clusters
#   Size 41: 3 clusters
#   Size 42: 1 clusters
#   Size 43: 2 clusters
#   Size 44: 1 clusters
#   Size 45: 2 clusters
#   Size 47: 9 clusters
#   Size 48: 15 clusters
#   Size 49: 152 clusters
# Missing outlet warnings: 3180
# \n=== FINAL RESULTS (win_01) ===
# Mean weighted frequency: 0.225
# Max weighted frequency: 1.120
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_02)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_02) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 128773.99
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.40
# Median surprisal weight: 0.00
# Cluster size distribution:
#   Size 1: 2714 clusters
#   Size 2: 226 clusters
#   Size 3: 114 clusters
#   Size 4: 139 clusters
#   Size 5: 139 clusters
#   Size 6: 144 clusters
#   Size 7: 77 clusters
#   Size 8: 82 clusters
#   Size 9: 65 clusters
#   Size 10: 49 clusters
#   Size 11: 66 clusters
#   Size 12: 45 clusters
#   Size 13: 53 clusters
#   Size 14: 51 clusters
#   Size 15: 21 clusters
#   Size 16: 14 clusters
#   Size 17: 11 clusters
#   Size 18: 11 clusters
#   Size 19: 13 clusters
#   Size 20: 8 clusters
#   Size 21: 17 clusters
#   Size 22: 13 clusters
#   Size 23: 11 clusters
#   Size 24: 6 clusters
#   Size 25: 3 clusters
#   Size 26: 5 clusters
#   Size 27: 16 clusters
#   Size 28: 9 clusters
#   Size 29: 8 clusters
#   Size 30: 12 clusters
#   Size 31: 4 clusters
#   Size 32: 2 clusters
#   Size 34: 9 clusters
#   Size 35: 18 clusters
#   Size 36: 2 clusters
#   Size 37: 5 clusters
#   Size 38: 3 clusters
#   Size 40: 6 clusters
#   Size 41: 1 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 46: 5 clusters
#   Size 47: 10 clusters
#   Size 48: 13 clusters
#   Size 49: 160 clusters
# Missing outlet warnings: 3846
# \n=== FINAL RESULTS (win_02) ===
# Mean weighted frequency: 0.210
# Max weighted frequency: 1.167
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_03)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_03) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 119583.63
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.37
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 3397 clusters
#   Size 2: 206 clusters
#   Size 3: 179 clusters
#   Size 4: 230 clusters
#   Size 5: 131 clusters
#   Size 6: 115 clusters
#   Size 7: 57 clusters
#   Size 8: 53 clusters
#   Size 9: 48 clusters
#   Size 10: 35 clusters
#   Size 11: 29 clusters
#   Size 12: 57 clusters
#   Size 13: 34 clusters
#   Size 14: 18 clusters
#   Size 15: 20 clusters
#   Size 16: 15 clusters
#   Size 17: 11 clusters
#   Size 18: 13 clusters
#   Size 19: 11 clusters
#   Size 20: 14 clusters
#   Size 21: 5 clusters
#   Size 22: 10 clusters
#   Size 23: 2 clusters
#   Size 24: 5 clusters
#   Size 25: 9 clusters
#   Size 26: 12 clusters
#   Size 27: 9 clusters
#   Size 28: 9 clusters
#   Size 29: 8 clusters
#   Size 30: 8 clusters
#   Size 31: 7 clusters
#   Size 32: 4 clusters
#   Size 33: 6 clusters
#   Size 34: 10 clusters
#   Size 35: 17 clusters
#   Size 36: 9 clusters
#   Size 37: 4 clusters
#   Size 38: 5 clusters
#   Size 39: 5 clusters
#   Size 40: 2 clusters
#   Size 41: 2 clusters
#   Size 42: 2 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 45: 13 clusters
#   Size 46: 8 clusters
#   Size 47: 33 clusters
#   Size 48: 71 clusters
#   Size 49: 69 clusters
# Missing outlet warnings: 7950
# \n=== FINAL RESULTS (win_03) ===
# Mean weighted frequency: 0.195
# Max weighted frequency: 1.401
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_04)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_04) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 132570.65
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.41
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 3037 clusters
#   Size 2: 175 clusters
#   Size 3: 162 clusters
#   Size 4: 114 clusters
#   Size 5: 127 clusters
#   Size 6: 82 clusters
#   Size 7: 55 clusters
#   Size 8: 73 clusters
#   Size 9: 37 clusters
#   Size 10: 57 clusters
#   Size 11: 49 clusters
#   Size 12: 65 clusters
#   Size 13: 43 clusters
#   Size 14: 36 clusters
#   Size 15: 53 clusters
#   Size 16: 11 clusters
#   Size 17: 12 clusters
#   Size 18: 10 clusters
#   Size 19: 9 clusters
#   Size 20: 9 clusters
#   Size 21: 13 clusters
#   Size 22: 4 clusters
#   Size 23: 14 clusters
#   Size 24: 7 clusters
#   Size 25: 6 clusters
#   Size 26: 13 clusters
#   Size 27: 7 clusters
#   Size 28: 12 clusters
#   Size 29: 5 clusters
#   Size 30: 9 clusters
#   Size 31: 10 clusters
#   Size 32: 7 clusters
#   Size 33: 29 clusters
#   Size 34: 3 clusters
#   Size 35: 6 clusters
#   Size 36: 10 clusters
#   Size 37: 5 clusters
#   Size 38: 1 clusters
#   Size 39: 3 clusters
#   Size 40: 3 clusters
#   Size 41: 2 clusters
#   Size 44: 1 clusters
#   Size 46: 14 clusters
#   Size 47: 14 clusters
#   Size 48: 91 clusters
#   Size 49: 67 clusters
# Missing outlet warnings: 5766
# \n=== FINAL RESULTS (win_04) ===
# Mean weighted frequency: 0.216
# Max weighted frequency: 1.128
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_05)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_05) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 130015.68
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.40
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 3007 clusters
#   Size 2: 201 clusters
#   Size 3: 149 clusters
#   Size 4: 128 clusters
#   Size 5: 150 clusters
#   Size 6: 108 clusters
#   Size 7: 69 clusters
#   Size 8: 52 clusters
#   Size 9: 44 clusters
#   Size 10: 55 clusters
#   Size 11: 37 clusters
#   Size 12: 33 clusters
#   Size 13: 26 clusters
#   Size 14: 27 clusters
#   Size 15: 41 clusters
#   Size 16: 22 clusters
#   Size 17: 18 clusters
#   Size 18: 11 clusters
#   Size 19: 4 clusters
#   Size 20: 12 clusters
#   Size 21: 7 clusters
#   Size 22: 20 clusters
#   Size 23: 19 clusters
#   Size 24: 9 clusters
#   Size 25: 17 clusters
#   Size 26: 8 clusters
#   Size 27: 9 clusters
#   Size 28: 8 clusters
#   Size 29: 2 clusters
#   Size 30: 5 clusters
#   Size 31: 11 clusters
#   Size 32: 8 clusters
#   Size 33: 23 clusters
#   Size 34: 7 clusters
#   Size 35: 8 clusters
#   Size 36: 5 clusters
#   Size 38: 4 clusters
#   Size 39: 7 clusters
#   Size 40: 4 clusters
#   Size 41: 3 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 2 clusters
#   Size 45: 9 clusters
#   Size 46: 7 clusters
#   Size 47: 6 clusters
#   Size 48: 97 clusters
#   Size 49: 68 clusters
# Missing outlet warnings: 5754
# \n=== FINAL RESULTS (win_05) ===
# Mean weighted frequency: 0.212
# Max weighted frequency: 1.040
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_06)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_06) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 134869.92
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.42
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 2904 clusters
#   Size 2: 176 clusters
#   Size 3: 128 clusters
#   Size 4: 115 clusters
#   Size 5: 129 clusters
#   Size 6: 85 clusters
#   Size 7: 100 clusters
#   Size 8: 76 clusters
#   Size 9: 74 clusters
#   Size 10: 31 clusters
#   Size 11: 43 clusters
#   Size 12: 37 clusters
#   Size 13: 49 clusters
#   Size 14: 29 clusters
#   Size 15: 19 clusters
#   Size 16: 41 clusters
#   Size 17: 19 clusters
#   Size 18: 14 clusters
#   Size 19: 10 clusters
#   Size 20: 4 clusters
#   Size 21: 7 clusters
#   Size 22: 10 clusters
#   Size 23: 22 clusters
#   Size 24: 11 clusters
#   Size 25: 7 clusters
#   Size 26: 6 clusters
#   Size 27: 7 clusters
#   Size 28: 4 clusters
#   Size 29: 7 clusters
#   Size 30: 7 clusters
#   Size 31: 7 clusters
#   Size 32: 19 clusters
#   Size 33: 10 clusters
#   Size 34: 5 clusters
#   Size 35: 19 clusters
#   Size 36: 5 clusters
#   Size 37: 3 clusters
#   Size 38: 11 clusters
#   Size 39: 4 clusters
#   Size 40: 5 clusters
#   Size 41: 3 clusters
#   Size 42: 3 clusters
#   Size 44: 6 clusters
#   Size 45: 7 clusters
#   Size 46: 1 clusters
#   Size 47: 10 clusters
#   Size 48: 89 clusters
#   Size 49: 67 clusters
# Missing outlet warnings: 4878
# \n=== FINAL RESULTS (win_06) ===
# Mean weighted frequency: 0.220
# Max weighted frequency: 1.234
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_07)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_07) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 143568.41
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.48
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 3254 clusters
#   Size 2: 186 clusters
#   Size 3: 157 clusters
#   Size 4: 93 clusters
#   Size 5: 134 clusters
#   Size 6: 104 clusters
#   Size 7: 104 clusters
#   Size 8: 84 clusters
#   Size 9: 45 clusters
#   Size 10: 50 clusters
#   Size 11: 63 clusters
#   Size 12: 34 clusters
#   Size 13: 64 clusters
#   Size 14: 44 clusters
#   Size 15: 21 clusters
#   Size 16: 5 clusters
#   Size 17: 16 clusters
#   Size 18: 12 clusters
#   Size 19: 10 clusters
#   Size 20: 7 clusters
#   Size 21: 13 clusters
#   Size 22: 15 clusters
#   Size 23: 9 clusters
#   Size 24: 15 clusters
#   Size 25: 5 clusters
#   Size 26: 8 clusters
#   Size 27: 9 clusters
#   Size 28: 13 clusters
#   Size 29: 4 clusters
#   Size 30: 7 clusters
#   Size 31: 15 clusters
#   Size 32: 35 clusters
#   Size 34: 8 clusters
#   Size 35: 10 clusters
#   Size 36: 9 clusters
#   Size 37: 3 clusters
#   Size 38: 1 clusters
#   Size 39: 4 clusters
#   Size 40: 2 clusters
#   Size 41: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 11 clusters
#   Size 44: 2 clusters
#   Size 45: 6 clusters
#   Size 46: 79 clusters
#   Size 48: 5 clusters
#   Size 49: 68 clusters
# Missing outlet warnings: 8298
# \n=== FINAL RESULTS (win_07) ===
# Mean weighted frequency: 0.234
# Max weighted frequency: 1.163
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_08)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_08) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 134518.97
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.43
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 3347 clusters
#   Size 2: 175 clusters
#   Size 3: 174 clusters
#   Size 4: 78 clusters
#   Size 5: 125 clusters
#   Size 6: 94 clusters
#   Size 7: 68 clusters
#   Size 8: 50 clusters
#   Size 9: 66 clusters
#   Size 10: 68 clusters
#   Size 11: 93 clusters
#   Size 12: 22 clusters
#   Size 13: 52 clusters
#   Size 14: 26 clusters
#   Size 15: 19 clusters
#   Size 16: 11 clusters
#   Size 17: 10 clusters
#   Size 18: 15 clusters
#   Size 19: 11 clusters
#   Size 20: 11 clusters
#   Size 21: 16 clusters
#   Size 22: 2 clusters
#   Size 23: 13 clusters
#   Size 24: 7 clusters
#   Size 25: 10 clusters
#   Size 26: 16 clusters
#   Size 27: 11 clusters
#   Size 28: 5 clusters
#   Size 29: 9 clusters
#   Size 30: 6 clusters
#   Size 31: 12 clusters
#   Size 32: 11 clusters
#   Size 33: 12 clusters
#   Size 35: 14 clusters
#   Size 36: 3 clusters
#   Size 37: 2 clusters
#   Size 38: 5 clusters
#   Size 39: 6 clusters
#   Size 40: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 7 clusters
#   Size 44: 6 clusters
#   Size 45: 7 clusters
#   Size 46: 93 clusters
#   Size 47: 2 clusters
#   Size 48: 5 clusters
#   Size 49: 73 clusters
# Missing outlet warnings: 8910
# \n=== FINAL RESULTS (win_08) ===
# Mean weighted frequency: 0.220
# Max weighted frequency: 1.079
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_09)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_09) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 127908.46
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.41
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 3514 clusters
#   Size 2: 195 clusters
#   Size 3: 223 clusters
#   Size 4: 155 clusters
#   Size 5: 150 clusters
#   Size 6: 97 clusters
#   Size 7: 64 clusters
#   Size 8: 45 clusters
#   Size 9: 49 clusters
#   Size 10: 49 clusters
#   Size 11: 74 clusters
#   Size 12: 51 clusters
#   Size 13: 22 clusters
#   Size 14: 33 clusters
#   Size 15: 9 clusters
#   Size 16: 12 clusters
#   Size 17: 7 clusters
#   Size 18: 8 clusters
#   Size 19: 10 clusters
#   Size 20: 16 clusters
#   Size 21: 21 clusters
#   Size 22: 9 clusters
#   Size 23: 5 clusters
#   Size 24: 11 clusters
#   Size 25: 19 clusters
#   Size 26: 5 clusters
#   Size 27: 9 clusters
#   Size 28: 11 clusters
#   Size 29: 2 clusters
#   Size 30: 5 clusters
#   Size 31: 2 clusters
#   Size 32: 8 clusters
#   Size 33: 7 clusters
#   Size 34: 20 clusters
#   Size 35: 8 clusters
#   Size 36: 5 clusters
#   Size 37: 3 clusters
#   Size 38: 4 clusters
#   Size 39: 2 clusters
#   Size 40: 4 clusters
#   Size 42: 1 clusters
#   Size 44: 12 clusters
#   Size 45: 7 clusters
#   Size 46: 93 clusters
#   Size 47: 1 clusters
#   Size 48: 6 clusters
#   Size 49: 75 clusters
# Missing outlet warnings: 10020
# \n=== FINAL RESULTS (win_09) ===
# Mean weighted frequency: 0.209
# Max weighted frequency: 1.230
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_10)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_10) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 135791.18
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.45
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 3423 clusters
#   Size 2: 200 clusters
#   Size 3: 227 clusters
#   Size 4: 82 clusters
#   Size 5: 124 clusters
#   Size 6: 86 clusters
#   Size 7: 96 clusters
#   Size 8: 92 clusters
#   Size 9: 40 clusters
#   Size 10: 80 clusters
#   Size 11: 62 clusters
#   Size 12: 21 clusters
#   Size 13: 24 clusters
#   Size 14: 25 clusters
#   Size 15: 34 clusters
#   Size 16: 21 clusters
#   Size 17: 17 clusters
#   Size 18: 15 clusters
#   Size 19: 10 clusters
#   Size 20: 11 clusters
#   Size 21: 15 clusters
#   Size 22: 17 clusters
#   Size 23: 14 clusters
#   Size 24: 6 clusters
#   Size 25: 19 clusters
#   Size 26: 11 clusters
#   Size 27: 4 clusters
#   Size 28: 7 clusters
#   Size 29: 17 clusters
#   Size 30: 7 clusters
#   Size 31: 13 clusters
#   Size 32: 3 clusters
#   Size 33: 3 clusters
#   Size 34: 4 clusters
#   Size 35: 2 clusters
#   Size 36: 1 clusters
#   Size 37: 3 clusters
#   Size 38: 3 clusters
#   Size 39: 11 clusters
#   Size 40: 1 clusters
#   Size 41: 3 clusters
#   Size 43: 7 clusters
#   Size 44: 6 clusters
#   Size 45: 11 clusters
#   Size 46: 88 clusters
#   Size 48: 3 clusters
#   Size 49: 72 clusters
# Missing outlet warnings: 9384
# \n=== FINAL RESULTS (win_10) ===
# Mean weighted frequency: 0.222
# Max weighted frequency: 1.055
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_11)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_11) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 133501.96
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.45
# Median surprisal weight: 0.16
# Cluster size distribution:
#   Size 1: 3924 clusters
#   Size 2: 207 clusters
#   Size 3: 174 clusters
#   Size 4: 130 clusters
#   Size 5: 141 clusters
#   Size 6: 139 clusters
#   Size 7: 69 clusters
#   Size 8: 113 clusters
#   Size 9: 52 clusters
#   Size 10: 39 clusters
#   Size 11: 31 clusters
#   Size 12: 17 clusters
#   Size 13: 38 clusters
#   Size 14: 25 clusters
#   Size 15: 19 clusters
#   Size 16: 15 clusters
#   Size 17: 11 clusters
#   Size 18: 12 clusters
#   Size 19: 11 clusters
#   Size 20: 9 clusters
#   Size 21: 17 clusters
#   Size 22: 6 clusters
#   Size 23: 9 clusters
#   Size 24: 5 clusters
#   Size 25: 9 clusters
#   Size 26: 10 clusters
#   Size 27: 6 clusters
#   Size 28: 11 clusters
#   Size 29: 14 clusters
#   Size 30: 18 clusters
#   Size 31: 13 clusters
#   Size 32: 3 clusters
#   Size 33: 3 clusters
#   Size 34: 4 clusters
#   Size 35: 5 clusters
#   Size 36: 6 clusters
#   Size 37: 2 clusters
#   Size 38: 7 clusters
#   Size 39: 3 clusters
#   Size 40: 3 clusters
#   Size 41: 10 clusters
#   Size 42: 6 clusters
#   Size 43: 23 clusters
#   Size 44: 83 clusters
#   Size 47: 1 clusters
#   Size 48: 5 clusters
#   Size 49: 68 clusters
# Missing outlet warnings: 12954
# \n=== FINAL RESULTS (win_11) ===
# Mean weighted frequency: 0.218
# Max weighted frequency: 1.110
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_12)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_12) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 130199.70
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.45
# Median surprisal weight: 0.19
# Cluster size distribution:
#   Size 1: 4515 clusters
#   Size 2: 184 clusters
#   Size 3: 129 clusters
#   Size 4: 112 clusters
#   Size 5: 140 clusters
#   Size 6: 118 clusters
#   Size 7: 99 clusters
#   Size 8: 41 clusters
#   Size 9: 44 clusters
#   Size 10: 50 clusters
#   Size 11: 27 clusters
#   Size 12: 29 clusters
#   Size 13: 27 clusters
#   Size 14: 23 clusters
#   Size 15: 25 clusters
#   Size 16: 16 clusters
#   Size 17: 11 clusters
#   Size 18: 8 clusters
#   Size 19: 16 clusters
#   Size 20: 12 clusters
#   Size 21: 16 clusters
#   Size 22: 10 clusters
#   Size 23: 7 clusters
#   Size 24: 11 clusters
#   Size 25: 9 clusters
#   Size 26: 8 clusters
#   Size 27: 7 clusters
#   Size 28: 14 clusters
#   Size 29: 8 clusters
#   Size 30: 15 clusters
#   Size 31: 7 clusters
#   Size 32: 9 clusters
#   Size 33: 5 clusters
#   Size 34: 1 clusters
#   Size 35: 2 clusters
#   Size 37: 3 clusters
#   Size 38: 6 clusters
#   Size 39: 5 clusters
#   Size 40: 3 clusters
#   Size 41: 6 clusters
#   Size 42: 20 clusters
#   Size 43: 96 clusters
#   Size 44: 4 clusters
#   Size 45: 1 clusters
#   Size 46: 1 clusters
#   Size 47: 1 clusters
#   Size 48: 5 clusters
#   Size 49: 69 clusters
# Missing outlet warnings: 15102
# \n=== FINAL RESULTS (win_12) ===
# Mean weighted frequency: 0.213
# Max weighted frequency: 1.075
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_13)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_13) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 128684.81
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.43
# Median surprisal weight: 0.19
# Cluster size distribution:
#   Size 1: 4279 clusters
#   Size 2: 229 clusters
#   Size 3: 186 clusters
#   Size 4: 129 clusters
#   Size 5: 148 clusters
#   Size 6: 78 clusters
#   Size 7: 60 clusters
#   Size 8: 58 clusters
#   Size 9: 30 clusters
#   Size 10: 81 clusters
#   Size 11: 28 clusters
#   Size 12: 27 clusters
#   Size 13: 23 clusters
#   Size 14: 16 clusters
#   Size 15: 12 clusters
#   Size 16: 13 clusters
#   Size 17: 18 clusters
#   Size 18: 5 clusters
#   Size 19: 9 clusters
#   Size 20: 10 clusters
#   Size 21: 5 clusters
#   Size 22: 13 clusters
#   Size 23: 8 clusters
#   Size 24: 8 clusters
#   Size 25: 11 clusters
#   Size 26: 4 clusters
#   Size 27: 8 clusters
#   Size 28: 4 clusters
#   Size 29: 9 clusters
#   Size 30: 13 clusters
#   Size 31: 13 clusters
#   Size 32: 10 clusters
#   Size 33: 8 clusters
#   Size 34: 7 clusters
#   Size 35: 4 clusters
#   Size 36: 4 clusters
#   Size 37: 16 clusters
#   Size 38: 6 clusters
#   Size 39: 8 clusters
#   Size 40: 7 clusters
#   Size 41: 36 clusters
#   Size 42: 18 clusters
#   Size 43: 12 clusters
#   Size 44: 51 clusters
#   Size 46: 1 clusters
#   Size 47: 3 clusters
#   Size 48: 6 clusters
#   Size 49: 69 clusters
# Missing outlet warnings: 13572
# \n=== FINAL RESULTS (win_13) ===
# Mean weighted frequency: 0.210
# Max weighted frequency: 1.087
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_14)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_14) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 139173.67
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.50
# Median surprisal weight: 0.22
# Cluster size distribution:
#   Size 1: 4323 clusters
#   Size 2: 164 clusters
#   Size 3: 150 clusters
#   Size 4: 99 clusters
#   Size 5: 168 clusters
#   Size 6: 86 clusters
#   Size 7: 124 clusters
#   Size 8: 57 clusters
#   Size 9: 57 clusters
#   Size 10: 52 clusters
#   Size 11: 39 clusters
#   Size 12: 27 clusters
#   Size 13: 19 clusters
#   Size 14: 61 clusters
#   Size 15: 19 clusters
#   Size 16: 15 clusters
#   Size 17: 20 clusters
#   Size 18: 5 clusters
#   Size 19: 11 clusters
#   Size 20: 12 clusters
#   Size 21: 18 clusters
#   Size 22: 18 clusters
#   Size 23: 7 clusters
#   Size 24: 15 clusters
#   Size 25: 10 clusters
#   Size 26: 8 clusters
#   Size 27: 3 clusters
#   Size 28: 5 clusters
#   Size 29: 7 clusters
#   Size 30: 4 clusters
#   Size 31: 12 clusters
#   Size 32: 7 clusters
#   Size 33: 9 clusters
#   Size 34: 2 clusters
#   Size 35: 7 clusters
#   Size 36: 1 clusters
#   Size 37: 5 clusters
#   Size 38: 1 clusters
#   Size 39: 2 clusters
#   Size 40: 12 clusters
#   Size 41: 16 clusters
#   Size 42: 95 clusters
#   Size 44: 1 clusters
#   Size 45: 1 clusters
#   Size 48: 4 clusters
#   Size 49: 70 clusters
# Missing outlet warnings: 15492
# \n=== FINAL RESULTS (win_14) ===
# Mean weighted frequency: 0.227
# Max weighted frequency: 1.173
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_15)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_15) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 138953.97
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.49
# Median surprisal weight: 0.22
# Cluster size distribution:
#   Size 1: 4250 clusters
#   Size 2: 165 clusters
#   Size 3: 114 clusters
#   Size 4: 141 clusters
#   Size 5: 211 clusters
#   Size 6: 108 clusters
#   Size 7: 110 clusters
#   Size 8: 119 clusters
#   Size 9: 56 clusters
#   Size 10: 21 clusters
#   Size 11: 29 clusters
#   Size 12: 19 clusters
#   Size 13: 23 clusters
#   Size 14: 17 clusters
#   Size 15: 10 clusters
#   Size 16: 20 clusters
#   Size 17: 17 clusters
#   Size 18: 3 clusters
#   Size 19: 8 clusters
#   Size 20: 23 clusters
#   Size 21: 12 clusters
#   Size 22: 17 clusters
#   Size 23: 8 clusters
#   Size 24: 13 clusters
#   Size 25: 10 clusters
#   Size 26: 12 clusters
#   Size 27: 4 clusters
#   Size 28: 5 clusters
#   Size 29: 8 clusters
#   Size 30: 7 clusters
#   Size 31: 2 clusters
#   Size 32: 9 clusters
#   Size 33: 11 clusters
#   Size 34: 8 clusters
#   Size 35: 15 clusters
#   Size 36: 9 clusters
#   Size 37: 11 clusters
#   Size 38: 2 clusters
#   Size 39: 9 clusters
#   Size 40: 10 clusters
#   Size 41: 27 clusters
#   Size 42: 67 clusters
#   Size 45: 1 clusters
#   Size 48: 5 clusters
#   Size 49: 69 clusters
# Missing outlet warnings: 15192
# \n=== FINAL RESULTS (win_15) ===
# Mean weighted frequency: 0.227
# Max weighted frequency: 1.204
# Non-zero frequency entries: 2352
# \nTemporal stability (ARI) summary:
#   Mean ARI: 0.360
#   Std  ARI: 0.109
#   Min  ARI: 0.183
#   Max  ARI: 1.000
# \nConsecutive-window drift:
#   mean ARI: 0.474
#   std  ARI: 0.160
# processing 521 clusterings for 49 outlets (win_00)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_00) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 131198.18
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.40
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 2766 clusters
#   Size 2: 228 clusters
#   Size 3: 139 clusters
#   Size 4: 117 clusters
#   Size 5: 119 clusters
#   Size 6: 95 clusters
#   Size 7: 68 clusters
#   Size 8: 64 clusters
#   Size 9: 80 clusters
#   Size 10: 63 clusters
#   Size 11: 70 clusters
#   Size 12: 50 clusters
#   Size 13: 47 clusters
#   Size 14: 36 clusters
#   Size 15: 22 clusters
#   Size 16: 12 clusters
#   Size 17: 15 clusters
#   Size 18: 9 clusters
#   Size 19: 15 clusters
#   Size 20: 16 clusters
#   Size 21: 10 clusters
#   Size 22: 6 clusters
#   Size 23: 7 clusters
#   Size 24: 6 clusters
#   Size 25: 9 clusters
#   Size 26: 5 clusters
#   Size 27: 15 clusters
#   Size 28: 12 clusters
#   Size 29: 6 clusters
#   Size 30: 9 clusters
#   Size 31: 5 clusters
#   Size 32: 11 clusters
#   Size 33: 18 clusters
#   Size 34: 4 clusters
#   Size 35: 3 clusters
#   Size 36: 7 clusters
#   Size 37: 4 clusters
#   Size 38: 3 clusters
#   Size 39: 5 clusters
#   Size 40: 6 clusters
#   Size 41: 3 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 45: 16 clusters
#   Size 46: 11 clusters
#   Size 47: 1 clusters
#   Size 48: 31 clusters
#   Size 49: 129 clusters
# Missing outlet warnings: 3456
# \n=== FINAL RESULTS (win_00) ===
# Mean weighted frequency: 0.214
# Max weighted frequency: 1.110
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_01)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_01) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 137573.00
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.43
# Median surprisal weight: 0.00
# Cluster size distribution:
#   Size 1: 2639 clusters
#   Size 2: 162 clusters
#   Size 3: 106 clusters
#   Size 4: 132 clusters
#   Size 5: 147 clusters
#   Size 6: 99 clusters
#   Size 7: 66 clusters
#   Size 8: 52 clusters
#   Size 9: 50 clusters
#   Size 10: 112 clusters
#   Size 11: 64 clusters
#   Size 12: 64 clusters
#   Size 13: 29 clusters
#   Size 14: 16 clusters
#   Size 15: 14 clusters
#   Size 16: 27 clusters
#   Size 17: 32 clusters
#   Size 18: 12 clusters
#   Size 19: 5 clusters
#   Size 20: 15 clusters
#   Size 21: 11 clusters
#   Size 22: 24 clusters
#   Size 23: 14 clusters
#   Size 24: 12 clusters
#   Size 25: 16 clusters
#   Size 26: 27 clusters
#   Size 27: 8 clusters
#   Size 28: 10 clusters
#   Size 29: 11 clusters
#   Size 30: 8 clusters
#   Size 31: 5 clusters
#   Size 32: 7 clusters
#   Size 33: 3 clusters
#   Size 34: 2 clusters
#   Size 35: 2 clusters
#   Size 36: 1 clusters
#   Size 37: 4 clusters
#   Size 38: 5 clusters
#   Size 39: 11 clusters
#   Size 40: 2 clusters
#   Size 41: 3 clusters
#   Size 42: 1 clusters
#   Size 43: 2 clusters
#   Size 44: 1 clusters
#   Size 45: 2 clusters
#   Size 47: 9 clusters
#   Size 48: 15 clusters
#   Size 49: 152 clusters
# Missing outlet warnings: 3180
# \n=== FINAL RESULTS (win_01) ===
# Mean weighted frequency: 0.225
# Max weighted frequency: 1.120
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_02)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_02) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 128773.99
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.40
# Median surprisal weight: 0.00
# Cluster size distribution:
#   Size 1: 2714 clusters
#   Size 2: 226 clusters
#   Size 3: 114 clusters
#   Size 4: 139 clusters
#   Size 5: 139 clusters
#   Size 6: 144 clusters
#   Size 7: 77 clusters
#   Size 8: 82 clusters
#   Size 9: 65 clusters
#   Size 10: 49 clusters
#   Size 11: 66 clusters
#   Size 12: 45 clusters
#   Size 13: 53 clusters
#   Size 14: 51 clusters
#   Size 15: 21 clusters
#   Size 16: 14 clusters
#   Size 17: 11 clusters
#   Size 18: 11 clusters
#   Size 19: 13 clusters
#   Size 20: 8 clusters
#   Size 21: 17 clusters
#   Size 22: 13 clusters
#   Size 23: 11 clusters
#   Size 24: 6 clusters
#   Size 25: 3 clusters
#   Size 26: 5 clusters
#   Size 27: 16 clusters
#   Size 28: 9 clusters
#   Size 29: 8 clusters
#   Size 30: 12 clusters
#   Size 31: 4 clusters
#   Size 32: 2 clusters
#   Size 34: 9 clusters
#   Size 35: 18 clusters
#   Size 36: 2 clusters
#   Size 37: 5 clusters
#   Size 38: 3 clusters
#   Size 40: 6 clusters
#   Size 41: 1 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 46: 5 clusters
#   Size 47: 10 clusters
#   Size 48: 13 clusters
#   Size 49: 160 clusters
# Missing outlet warnings: 3846
# \n=== FINAL RESULTS (win_02) ===
# Mean weighted frequency: 0.210
# Max weighted frequency: 1.167
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_03)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_03) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 119583.63
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.37
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 3397 clusters
#   Size 2: 206 clusters
#   Size 3: 179 clusters
#   Size 4: 230 clusters
#   Size 5: 131 clusters
#   Size 6: 115 clusters
#   Size 7: 57 clusters
#   Size 8: 53 clusters
#   Size 9: 48 clusters
#   Size 10: 35 clusters
#   Size 11: 29 clusters
#   Size 12: 57 clusters
#   Size 13: 34 clusters
#   Size 14: 18 clusters
#   Size 15: 20 clusters
#   Size 16: 15 clusters
#   Size 17: 11 clusters
#   Size 18: 13 clusters
#   Size 19: 11 clusters
#   Size 20: 14 clusters
#   Size 21: 5 clusters
#   Size 22: 10 clusters
#   Size 23: 2 clusters
#   Size 24: 5 clusters
#   Size 25: 9 clusters
#   Size 26: 12 clusters
#   Size 27: 9 clusters
#   Size 28: 9 clusters
#   Size 29: 8 clusters
#   Size 30: 8 clusters
#   Size 31: 7 clusters
#   Size 32: 4 clusters
#   Size 33: 6 clusters
#   Size 34: 10 clusters
#   Size 35: 17 clusters
#   Size 36: 9 clusters
#   Size 37: 4 clusters
#   Size 38: 5 clusters
#   Size 39: 5 clusters
#   Size 40: 2 clusters
#   Size 41: 2 clusters
#   Size 42: 2 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 45: 13 clusters
#   Size 46: 8 clusters
#   Size 47: 33 clusters
#   Size 48: 71 clusters
#   Size 49: 69 clusters
# Missing outlet warnings: 7950
# \n=== FINAL RESULTS (win_03) ===
# Mean weighted frequency: 0.195
# Max weighted frequency: 1.401
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_04)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_04) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 132570.65
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.41
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 3037 clusters
#   Size 2: 175 clusters
#   Size 3: 162 clusters
#   Size 4: 114 clusters
#   Size 5: 127 clusters
#   Size 6: 82 clusters
#   Size 7: 55 clusters
#   Size 8: 73 clusters
#   Size 9: 37 clusters
#   Size 10: 57 clusters
#   Size 11: 49 clusters
#   Size 12: 65 clusters
#   Size 13: 43 clusters
#   Size 14: 36 clusters
#   Size 15: 53 clusters
#   Size 16: 11 clusters
#   Size 17: 12 clusters
#   Size 18: 10 clusters
#   Size 19: 9 clusters
#   Size 20: 9 clusters
#   Size 21: 13 clusters
#   Size 22: 4 clusters
#   Size 23: 14 clusters
#   Size 24: 7 clusters
#   Size 25: 6 clusters
#   Size 26: 13 clusters
#   Size 27: 7 clusters
#   Size 28: 12 clusters
#   Size 29: 5 clusters
#   Size 30: 9 clusters
#   Size 31: 10 clusters
#   Size 32: 7 clusters
#   Size 33: 29 clusters
#   Size 34: 3 clusters
#   Size 35: 6 clusters
#   Size 36: 10 clusters
#   Size 37: 5 clusters
#   Size 38: 1 clusters
#   Size 39: 3 clusters
#   Size 40: 3 clusters
#   Size 41: 2 clusters
#   Size 44: 1 clusters
#   Size 46: 14 clusters
#   Size 47: 14 clusters
#   Size 48: 91 clusters
#   Size 49: 67 clusters
# Missing outlet warnings: 5766
# \n=== FINAL RESULTS (win_04) ===
# Mean weighted frequency: 0.216
# Max weighted frequency: 1.128
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_05)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_05) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 130015.68
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.40
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 3007 clusters
#   Size 2: 201 clusters
#   Size 3: 149 clusters
#   Size 4: 128 clusters
#   Size 5: 150 clusters
#   Size 6: 108 clusters
#   Size 7: 69 clusters
#   Size 8: 52 clusters
#   Size 9: 44 clusters
#   Size 10: 55 clusters
#   Size 11: 37 clusters
#   Size 12: 33 clusters
#   Size 13: 26 clusters
#   Size 14: 27 clusters
#   Size 15: 41 clusters
#   Size 16: 22 clusters
#   Size 17: 18 clusters
#   Size 18: 11 clusters
#   Size 19: 4 clusters
#   Size 20: 12 clusters
#   Size 21: 7 clusters
#   Size 22: 20 clusters
#   Size 23: 19 clusters
#   Size 24: 9 clusters
#   Size 25: 17 clusters
#   Size 26: 8 clusters
#   Size 27: 9 clusters
#   Size 28: 8 clusters
#   Size 29: 2 clusters
#   Size 30: 5 clusters
#   Size 31: 11 clusters
#   Size 32: 8 clusters
#   Size 33: 23 clusters
#   Size 34: 7 clusters
#   Size 35: 8 clusters
#   Size 36: 5 clusters
#   Size 38: 4 clusters
#   Size 39: 7 clusters
#   Size 40: 4 clusters
#   Size 41: 3 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 2 clusters
#   Size 45: 9 clusters
#   Size 46: 7 clusters
#   Size 47: 6 clusters
#   Size 48: 97 clusters
#   Size 49: 68 clusters
# Missing outlet warnings: 5754
# \n=== FINAL RESULTS (win_05) ===
# Mean weighted frequency: 0.212
# Max weighted frequency: 1.040
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_06)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_06) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 134869.92
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.42
# Median surprisal weight: 0.03
# Cluster size distribution:
#   Size 1: 2904 clusters
#   Size 2: 176 clusters
#   Size 3: 128 clusters
#   Size 4: 115 clusters
#   Size 5: 129 clusters
#   Size 6: 85 clusters
#   Size 7: 100 clusters
#   Size 8: 76 clusters
#   Size 9: 74 clusters
#   Size 10: 31 clusters
#   Size 11: 43 clusters
#   Size 12: 37 clusters
#   Size 13: 49 clusters
#   Size 14: 29 clusters
#   Size 15: 19 clusters
#   Size 16: 41 clusters
#   Size 17: 19 clusters
#   Size 18: 14 clusters
#   Size 19: 10 clusters
#   Size 20: 4 clusters
#   Size 21: 7 clusters
#   Size 22: 10 clusters
#   Size 23: 22 clusters
#   Size 24: 11 clusters
#   Size 25: 7 clusters
#   Size 26: 6 clusters
#   Size 27: 7 clusters
#   Size 28: 4 clusters
#   Size 29: 7 clusters
#   Size 30: 7 clusters
#   Size 31: 7 clusters
#   Size 32: 19 clusters
#   Size 33: 10 clusters
#   Size 34: 5 clusters
#   Size 35: 19 clusters
#   Size 36: 5 clusters
#   Size 37: 3 clusters
#   Size 38: 11 clusters
#   Size 39: 4 clusters
#   Size 40: 5 clusters
#   Size 41: 3 clusters
#   Size 42: 3 clusters
#   Size 44: 6 clusters
#   Size 45: 7 clusters
#   Size 46: 1 clusters
#   Size 47: 10 clusters
#   Size 48: 89 clusters
#   Size 49: 67 clusters
# Missing outlet warnings: 4878
# \n=== FINAL RESULTS (win_06) ===
# Mean weighted frequency: 0.220
# Max weighted frequency: 1.234
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_07)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_07) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 143568.41
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.48
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 3254 clusters
#   Size 2: 186 clusters
#   Size 3: 157 clusters
#   Size 4: 93 clusters
#   Size 5: 134 clusters
#   Size 6: 104 clusters
#   Size 7: 104 clusters
#   Size 8: 84 clusters
#   Size 9: 45 clusters
#   Size 10: 50 clusters
#   Size 11: 63 clusters
#   Size 12: 34 clusters
#   Size 13: 64 clusters
#   Size 14: 44 clusters
#   Size 15: 21 clusters
#   Size 16: 5 clusters
#   Size 17: 16 clusters
#   Size 18: 12 clusters
#   Size 19: 10 clusters
#   Size 20: 7 clusters
#   Size 21: 13 clusters
#   Size 22: 15 clusters
#   Size 23: 9 clusters
#   Size 24: 15 clusters
#   Size 25: 5 clusters
#   Size 26: 8 clusters
#   Size 27: 9 clusters
#   Size 28: 13 clusters
#   Size 29: 4 clusters
#   Size 30: 7 clusters
#   Size 31: 15 clusters
#   Size 32: 35 clusters
#   Size 34: 8 clusters
#   Size 35: 10 clusters
#   Size 36: 9 clusters
#   Size 37: 3 clusters
#   Size 38: 1 clusters
#   Size 39: 4 clusters
#   Size 40: 2 clusters
#   Size 41: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 11 clusters
#   Size 44: 2 clusters
#   Size 45: 6 clusters
#   Size 46: 79 clusters
#   Size 48: 5 clusters
#   Size 49: 68 clusters
# Missing outlet warnings: 8298
# \n=== FINAL RESULTS (win_07) ===
# Mean weighted frequency: 0.234
# Max weighted frequency: 1.163
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_08)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_08) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 134518.97
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.43
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 3347 clusters
#   Size 2: 175 clusters
#   Size 3: 174 clusters
#   Size 4: 78 clusters
#   Size 5: 125 clusters
#   Size 6: 94 clusters
#   Size 7: 68 clusters
#   Size 8: 50 clusters
#   Size 9: 66 clusters
#   Size 10: 68 clusters
#   Size 11: 93 clusters
#   Size 12: 22 clusters
#   Size 13: 52 clusters
#   Size 14: 26 clusters
#   Size 15: 19 clusters
#   Size 16: 11 clusters
#   Size 17: 10 clusters
#   Size 18: 15 clusters
#   Size 19: 11 clusters
#   Size 20: 11 clusters
#   Size 21: 16 clusters
#   Size 22: 2 clusters
#   Size 23: 13 clusters
#   Size 24: 7 clusters
#   Size 25: 10 clusters
#   Size 26: 16 clusters
#   Size 27: 11 clusters
#   Size 28: 5 clusters
#   Size 29: 9 clusters
#   Size 30: 6 clusters
#   Size 31: 12 clusters
#   Size 32: 11 clusters
#   Size 33: 12 clusters
#   Size 35: 14 clusters
#   Size 36: 3 clusters
#   Size 37: 2 clusters
#   Size 38: 5 clusters
#   Size 39: 6 clusters
#   Size 40: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 7 clusters
#   Size 44: 6 clusters
#   Size 45: 7 clusters
#   Size 46: 93 clusters
#   Size 47: 2 clusters
#   Size 48: 5 clusters
#   Size 49: 73 clusters
# Missing outlet warnings: 8910
# \n=== FINAL RESULTS (win_08) ===
# Mean weighted frequency: 0.220
# Max weighted frequency: 1.079
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_09)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_09) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 127908.46
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.41
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 3514 clusters
#   Size 2: 195 clusters
#   Size 3: 223 clusters
#   Size 4: 155 clusters
#   Size 5: 150 clusters
#   Size 6: 97 clusters
#   Size 7: 64 clusters
#   Size 8: 45 clusters
#   Size 9: 49 clusters
#   Size 10: 49 clusters
#   Size 11: 74 clusters
#   Size 12: 51 clusters
#   Size 13: 22 clusters
#   Size 14: 33 clusters
#   Size 15: 9 clusters
#   Size 16: 12 clusters
#   Size 17: 7 clusters
#   Size 18: 8 clusters
#   Size 19: 10 clusters
#   Size 20: 16 clusters
#   Size 21: 21 clusters
#   Size 22: 9 clusters
#   Size 23: 5 clusters
#   Size 24: 11 clusters
#   Size 25: 19 clusters
#   Size 26: 5 clusters
#   Size 27: 9 clusters
#   Size 28: 11 clusters
#   Size 29: 2 clusters
#   Size 30: 5 clusters
#   Size 31: 2 clusters
#   Size 32: 8 clusters
#   Size 33: 7 clusters
#   Size 34: 20 clusters
#   Size 35: 8 clusters
#   Size 36: 5 clusters
#   Size 37: 3 clusters
#   Size 38: 4 clusters
#   Size 39: 2 clusters
#   Size 40: 4 clusters
#   Size 42: 1 clusters
#   Size 44: 12 clusters
#   Size 45: 7 clusters
#   Size 46: 93 clusters
#   Size 47: 1 clusters
#   Size 48: 6 clusters
#   Size 49: 75 clusters
# Missing outlet warnings: 10020
# \n=== FINAL RESULTS (win_09) ===
# Mean weighted frequency: 0.209
# Max weighted frequency: 1.230
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_10)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_10) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 135791.18
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.45
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 3423 clusters
#   Size 2: 200 clusters
#   Size 3: 227 clusters
#   Size 4: 82 clusters
#   Size 5: 124 clusters
#   Size 6: 86 clusters
#   Size 7: 96 clusters
#   Size 8: 92 clusters
#   Size 9: 40 clusters
#   Size 10: 80 clusters
#   Size 11: 62 clusters
#   Size 12: 21 clusters
#   Size 13: 24 clusters
#   Size 14: 25 clusters
#   Size 15: 34 clusters
#   Size 16: 21 clusters
#   Size 17: 17 clusters
#   Size 18: 15 clusters
#   Size 19: 10 clusters
#   Size 20: 11 clusters
#   Size 21: 15 clusters
#   Size 22: 17 clusters
#   Size 23: 14 clusters
#   Size 24: 6 clusters
#   Size 25: 19 clusters
#   Size 26: 11 clusters
#   Size 27: 4 clusters
#   Size 28: 7 clusters
#   Size 29: 17 clusters
#   Size 30: 7 clusters
#   Size 31: 13 clusters
#   Size 32: 3 clusters
#   Size 33: 3 clusters
#   Size 34: 4 clusters
#   Size 35: 2 clusters
#   Size 36: 1 clusters
#   Size 37: 3 clusters
#   Size 38: 3 clusters
#   Size 39: 11 clusters
#   Size 40: 1 clusters
#   Size 41: 3 clusters
#   Size 43: 7 clusters
#   Size 44: 6 clusters
#   Size 45: 11 clusters
#   Size 46: 88 clusters
#   Size 48: 3 clusters
#   Size 49: 72 clusters
# Missing outlet warnings: 9384
# \n=== FINAL RESULTS (win_10) ===
# Mean weighted frequency: 0.222
# Max weighted frequency: 1.055
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_11)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_11) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 133501.96
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.45
# Median surprisal weight: 0.16
# Cluster size distribution:
#   Size 1: 3924 clusters
#   Size 2: 207 clusters
#   Size 3: 174 clusters
#   Size 4: 130 clusters
#   Size 5: 141 clusters
#   Size 6: 139 clusters
#   Size 7: 69 clusters
#   Size 8: 113 clusters
#   Size 9: 52 clusters
#   Size 10: 39 clusters
#   Size 11: 31 clusters
#   Size 12: 17 clusters
#   Size 13: 38 clusters
#   Size 14: 25 clusters
#   Size 15: 19 clusters
#   Size 16: 15 clusters
#   Size 17: 11 clusters
#   Size 18: 12 clusters
#   Size 19: 11 clusters
#   Size 20: 9 clusters
#   Size 21: 17 clusters
#   Size 22: 6 clusters
#   Size 23: 9 clusters
#   Size 24: 5 clusters
#   Size 25: 9 clusters
#   Size 26: 10 clusters
#   Size 27: 6 clusters
#   Size 28: 11 clusters
#   Size 29: 14 clusters
#   Size 30: 18 clusters
#   Size 31: 13 clusters
#   Size 32: 3 clusters
#   Size 33: 3 clusters
#   Size 34: 4 clusters
#   Size 35: 5 clusters
#   Size 36: 6 clusters
#   Size 37: 2 clusters
#   Size 38: 7 clusters
#   Size 39: 3 clusters
#   Size 40: 3 clusters
#   Size 41: 10 clusters
#   Size 42: 6 clusters
#   Size 43: 23 clusters
#   Size 44: 83 clusters
#   Size 47: 1 clusters
#   Size 48: 5 clusters
#   Size 49: 68 clusters
# Missing outlet warnings: 12954
# \n=== FINAL RESULTS (win_11) ===
# Mean weighted frequency: 0.218
# Max weighted frequency: 1.110
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_12)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_12) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 130199.70
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.45
# Median surprisal weight: 0.19
# Cluster size distribution:
#   Size 1: 4515 clusters
#   Size 2: 184 clusters
#   Size 3: 129 clusters
#   Size 4: 112 clusters
#   Size 5: 140 clusters
#   Size 6: 118 clusters
#   Size 7: 99 clusters
#   Size 8: 41 clusters
#   Size 9: 44 clusters
#   Size 10: 50 clusters
#   Size 11: 27 clusters
#   Size 12: 29 clusters
#   Size 13: 27 clusters
#   Size 14: 23 clusters
#   Size 15: 25 clusters
#   Size 16: 16 clusters
#   Size 17: 11 clusters
#   Size 18: 8 clusters
#   Size 19: 16 clusters
#   Size 20: 12 clusters
#   Size 21: 16 clusters
#   Size 22: 10 clusters
#   Size 23: 7 clusters
#   Size 24: 11 clusters
#   Size 25: 9 clusters
#   Size 26: 8 clusters
#   Size 27: 7 clusters
#   Size 28: 14 clusters
#   Size 29: 8 clusters
#   Size 30: 15 clusters
#   Size 31: 7 clusters
#   Size 32: 9 clusters
#   Size 33: 5 clusters
#   Size 34: 1 clusters
#   Size 35: 2 clusters
#   Size 37: 3 clusters
#   Size 38: 6 clusters
#   Size 39: 5 clusters
#   Size 40: 3 clusters
#   Size 41: 6 clusters
#   Size 42: 20 clusters
#   Size 43: 96 clusters
#   Size 44: 4 clusters
#   Size 45: 1 clusters
#   Size 46: 1 clusters
#   Size 47: 1 clusters
#   Size 48: 5 clusters
#   Size 49: 69 clusters
# Missing outlet warnings: 15102
# \n=== FINAL RESULTS (win_12) ===
# Mean weighted frequency: 0.213
# Max weighted frequency: 1.075
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_13)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_13) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 128684.81
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.43
# Median surprisal weight: 0.19
# Cluster size distribution:
#   Size 1: 4279 clusters
#   Size 2: 229 clusters
#   Size 3: 186 clusters
#   Size 4: 129 clusters
#   Size 5: 148 clusters
#   Size 6: 78 clusters
#   Size 7: 60 clusters
#   Size 8: 58 clusters
#   Size 9: 30 clusters
#   Size 10: 81 clusters
#   Size 11: 28 clusters
#   Size 12: 27 clusters
#   Size 13: 23 clusters
#   Size 14: 16 clusters
#   Size 15: 12 clusters
#   Size 16: 13 clusters
#   Size 17: 18 clusters
#   Size 18: 5 clusters
#   Size 19: 9 clusters
#   Size 20: 10 clusters
#   Size 21: 5 clusters
#   Size 22: 13 clusters
#   Size 23: 8 clusters
#   Size 24: 8 clusters
#   Size 25: 11 clusters
#   Size 26: 4 clusters
#   Size 27: 8 clusters
#   Size 28: 4 clusters
#   Size 29: 9 clusters
#   Size 30: 13 clusters
#   Size 31: 13 clusters
#   Size 32: 10 clusters
#   Size 33: 8 clusters
#   Size 34: 7 clusters
#   Size 35: 4 clusters
#   Size 36: 4 clusters
#   Size 37: 16 clusters
#   Size 38: 6 clusters
#   Size 39: 8 clusters
#   Size 40: 7 clusters
#   Size 41: 36 clusters
#   Size 42: 18 clusters
#   Size 43: 12 clusters
#   Size 44: 51 clusters
#   Size 46: 1 clusters
#   Size 47: 3 clusters
#   Size 48: 6 clusters
#   Size 49: 69 clusters
# Missing outlet warnings: 13572
# \n=== FINAL RESULTS (win_13) ===
# Mean weighted frequency: 0.210
# Max weighted frequency: 1.087
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_14)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_14) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 139173.67
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.50
# Median surprisal weight: 0.22
# Cluster size distribution:
#   Size 1: 4323 clusters
#   Size 2: 164 clusters
#   Size 3: 150 clusters
#   Size 4: 99 clusters
#   Size 5: 168 clusters
#   Size 6: 86 clusters
#   Size 7: 124 clusters
#   Size 8: 57 clusters
#   Size 9: 57 clusters
#   Size 10: 52 clusters
#   Size 11: 39 clusters
#   Size 12: 27 clusters
#   Size 13: 19 clusters
#   Size 14: 61 clusters
#   Size 15: 19 clusters
#   Size 16: 15 clusters
#   Size 17: 20 clusters
#   Size 18: 5 clusters
#   Size 19: 11 clusters
#   Size 20: 12 clusters
#   Size 21: 18 clusters
#   Size 22: 18 clusters
#   Size 23: 7 clusters
#   Size 24: 15 clusters
#   Size 25: 10 clusters
#   Size 26: 8 clusters
#   Size 27: 3 clusters
#   Size 28: 5 clusters
#   Size 29: 7 clusters
#   Size 30: 4 clusters
#   Size 31: 12 clusters
#   Size 32: 7 clusters
#   Size 33: 9 clusters
#   Size 34: 2 clusters
#   Size 35: 7 clusters
#   Size 36: 1 clusters
#   Size 37: 5 clusters
#   Size 38: 1 clusters
#   Size 39: 2 clusters
#   Size 40: 12 clusters
#   Size 41: 16 clusters
#   Size 42: 95 clusters
#   Size 44: 1 clusters
#   Size 45: 1 clusters
#   Size 48: 4 clusters
#   Size 49: 70 clusters
# Missing outlet warnings: 15492
# \n=== FINAL RESULTS (win_14) ===
# Mean weighted frequency: 0.227
# Max weighted frequency: 1.173
# Non-zero frequency entries: 2352
# processing 521 clusterings for 49 outlets (win_15)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (win_15) ===
# Surprisal weighting: enabled
# Total clusterings processed: 521
# Total weight sum: 138953.97
# Surprisal weight range: -0.00 to 4.61
# Mean surprisal weight: 0.49
# Median surprisal weight: 0.22
# Cluster size distribution:
#   Size 1: 4250 clusters
#   Size 2: 165 clusters
#   Size 3: 114 clusters
#   Size 4: 141 clusters
#   Size 5: 211 clusters
#   Size 6: 108 clusters
#   Size 7: 110 clusters
#   Size 8: 119 clusters
#   Size 9: 56 clusters
#   Size 10: 21 clusters
#   Size 11: 29 clusters
#   Size 12: 19 clusters
#   Size 13: 23 clusters
#   Size 14: 17 clusters
#   Size 15: 10 clusters
#   Size 16: 20 clusters
#   Size 17: 17 clusters
#   Size 18: 3 clusters
#   Size 19: 8 clusters
#   Size 20: 23 clusters
#   Size 21: 12 clusters
#   Size 22: 17 clusters
#   Size 23: 8 clusters
#   Size 24: 13 clusters
#   Size 25: 10 clusters
#   Size 26: 12 clusters
#   Size 27: 4 clusters
#   Size 28: 5 clusters
#   Size 29: 8 clusters
#   Size 30: 7 clusters
#   Size 31: 2 clusters
#   Size 32: 9 clusters
#   Size 33: 11 clusters
#   Size 34: 8 clusters
#   Size 35: 15 clusters
#   Size 36: 9 clusters
#   Size 37: 11 clusters
#   Size 38: 2 clusters
#   Size 39: 9 clusters
#   Size 40: 10 clusters
#   Size 41: 27 clusters
#   Size 42: 67 clusters
#   Size 45: 1 clusters
#   Size 48: 5 clusters
#   Size 49: 69 clusters
# Missing outlet warnings: 15192
# \n=== FINAL RESULTS (win_15) ===
# Mean weighted frequency: 0.227
# Max weighted frequency: 1.204
# Non-zero frequency entries: 2352
#   Temporal trend: slope = 0.002 (increasing)
#   Stability range: 0.282 – 1.000
# \nLag similarity profile:
#   lag 1: mean ARI = 0.474
#   lag 2: mean ARI = 0.412
#   lag 3: mean ARI = 0.394
#   lag 4: mean ARI = 0.383
#   lag 5: mean ARI = 0.384
#   lag 6: mean ARI = 0.359

# %%
# %%

# =============================================================================
# 1.5. EXCLUSION ANALYSIS - METHODS FILTERED BY COMMUNITY COUNT
# =============================================================================

# run exclusion analysis and apply filter
analyzer.analyze_exclusions(COLORS)
# Out:
# \n=== EXCLUSION ANALYSIS ===
# Total results: 8336
# Excluded results (k=1 or k=n_outlets): 2145 (25.7%)
# \n--- Exclusion by Network Method ---
#                     method  total  excluded_count  excluded_fraction
# 0             cooccurrence    976             142              0.145
# 1                  jaccard    976             159              0.163
# 2                     dice    976             146              0.150
# 3                   cosine    896             569              0.635
# 4              correlation    720             395              0.549
# 5                      pmi    976              57              0.058
# 6                     lift    896             379              0.423
# 7         tfidf_similarity    976             146              0.150
# 8  conditional_probability    944             152              0.161
# \n--- Exclusion by Community Method ---
#                  method  total  excluded_count  excluded_fraction
# 0               louvain   1296             221              0.171
# 1                leiden   1008             482              0.478
# 2     label_propagation    144              63              0.438
# 3         girvan_newman    144               0              0.000
# 4               infomap    864             768              0.889
# 5   spectral_clustering   2304               0              0.000
# 6  threshold_components    720             244              0.339
# 7               k_cores    480             106              0.221
# 8           fast_greedy    224              32              0.143
# 9              walktrap   1152             229              0.199
# \nApplying exclusion filter: keeping 2 ≤ k ≤ 48
# Results after exclusion: 6191 (removed 2145)
# Retention rate: 74.3%

# %%
# %%

# =============================================================================
# 2. MODULARITY DISTRIBUTIONS ANALYSIS
# =============================================================================

print(f"\\n=== MODULARITY ANALYSIS ===")
viz.plot_modularity_analysis()
# Out:
# \n=== MODULARITY ANALYSIS ===
# modularity summary:
# mean: 0.102, std: 0.130
# min: -0.176, max: 0.633
# k-modularity correlation: 0.202

# %%
# %%

# =============================================================================
# 3. K DISTRIBUTION ANALYSIS
# =============================================================================

print(f"\\n=== K DISTRIBUTION ANALYSIS ===")
# viz.plot_k_distribution_analysis()
# Out:
# \n=== K DISTRIBUTION ANALYSIS ===

# %%
# %%

# =============================================================================
# 4. K vs MODULARITY RELATIONSHIP ANALYSIS
# =============================================================================

print("\\n=== K vs MODULARITY RELATIONSHIP ===")
viz.plot_k_modularity_relationship()
# Out:
# \n=== K vs MODULARITY RELATIONSHIP ===
# k-modularity correlation: 0.202

# %%
# %%

# =============================================================================
# 5. FREQUENCY MATRIX WITH SURPRISAL WEIGHTING
# =============================================================================

print("\\n=== FREQUENCY MATRIX WITH SURPRISAL WEIGHTING ===")

# use analyzer method for surprisal weighting comparison
surprisal_results = analyzer.analyze_surprisal_weighting_comparison(COLORS)

# extract results for further use
frequency_matrix_raw = surprisal_results['frequency_matrix_raw']
frequency_matrix_weighted = surprisal_results['frequency_matrix_weighted']

# recreate variables needed for later sections
off_diag_mask = ~np.eye(frequency_matrix_raw.shape[0], dtype=bool)
freq_values = frequency_matrix_weighted.values[off_diag_mask]
max_freq = freq_values.max() if (freq_values > 0).any() else 1.0

if max_freq > 0:
    norm_freq = frequency_matrix_weighted / max_freq
else:
    norm_freq = frequency_matrix_weighted.copy()
np.fill_diagonal(norm_freq.values, 1.0)

# use surprisal-weighted frequencies for significance testing
frequency_matrix = frequency_matrix_weighted
# Out:
# \n=== FREQUENCY MATRIX WITH SURPRISAL WEIGHTING ===
# \n=== SURPRISAL WEIGHTING COMPARISON ===
# aggregating all results with surprisal weighting...
# processing 6191 clusterings for 49 outlets (all_methods)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (all_methods) ===
# Surprisal weighting: disabled
# Total clusterings processed: 6191
# Total weight sum: 2956840.00
# Surprisal weight range: 1.00 to 1.00
# Mean surprisal weight: 1.00
# Median surprisal weight: 1.00
# Cluster size distribution:
#   Size 1: 36085 clusters
#   Size 2: 3079 clusters
#   Size 3: 2511 clusters
#   Size 4: 1994 clusters
#   Size 5: 2283 clusters
#   Size 6: 1638 clusters
#   Size 7: 1286 clusters
#   Size 8: 1111 clusters
#   Size 9: 837 clusters
#   Size 10: 892 clusters
#   Size 11: 804 clusters
#   Size 12: 598 clusters
#   Size 13: 573 clusters
#   Size 14: 483 clusters
#   Size 15: 358 clusters
#   Size 16: 270 clusters
#   Size 17: 245 clusters
#   Size 18: 163 clusters
#   Size 19: 163 clusters
#   Size 20: 189 clusters
#   Size 21: 203 clusters
#   Size 22: 194 clusters
#   Size 23: 169 clusters
#   Size 24: 147 clusters
#   Size 25: 169 clusters
#   Size 26: 158 clusters
#   Size 27: 132 clusters
#   Size 28: 139 clusters
#   Size 29: 125 clusters
#   Size 30: 140 clusters
#   Size 31: 138 clusters
#   Size 32: 153 clusters
#   Size 33: 147 clusters
#   Size 34: 94 clusters
#   Size 35: 140 clusters
#   Size 36: 77 clusters
#   Size 37: 73 clusters
#   Size 38: 67 clusters
#   Size 39: 85 clusters
#   Size 40: 66 clusters
#   Size 41: 105 clusters
#   Size 42: 164 clusters
#   Size 43: 114 clusters
#   Size 44: 123 clusters
#   Size 45: 69 clusters
#   Size 46: 287 clusters
#   Size 47: 67 clusters
#   Size 48: 367 clusters
# Missing outlet warnings: 69954
# \n=== FINAL RESULTS (all_methods) ===
# Mean weighted frequency: 0.406
# Max weighted frequency: 0.823
# Non-zero frequency entries: 2352
# aggregating all results with surprisal weighting...
# processing 6191 clusterings for 49 outlets (all_methods)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (all_methods) ===
# Surprisal weighting: enabled
# Total clusterings processed: 6191
# Total weight sum: 2079952.96
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.70
# Median surprisal weight: 0.41
# Cluster size distribution:
#   Size 1: 36085 clusters
#   Size 2: 3079 clusters
#   Size 3: 2511 clusters
#   Size 4: 1994 clusters
#   Size 5: 2283 clusters
#   Size 6: 1638 clusters
#   Size 7: 1286 clusters
#   Size 8: 1111 clusters
#   Size 9: 837 clusters
#   Size 10: 892 clusters
#   Size 11: 804 clusters
#   Size 12: 598 clusters
#   Size 13: 573 clusters
#   Size 14: 483 clusters
#   Size 15: 358 clusters
#   Size 16: 270 clusters
#   Size 17: 245 clusters
#   Size 18: 163 clusters
#   Size 19: 163 clusters
#   Size 20: 189 clusters
#   Size 21: 203 clusters
#   Size 22: 194 clusters
#   Size 23: 169 clusters
#   Size 24: 147 clusters
#   Size 25: 169 clusters
#   Size 26: 158 clusters
#   Size 27: 132 clusters
#   Size 28: 139 clusters
#   Size 29: 125 clusters
#   Size 30: 140 clusters
#   Size 31: 138 clusters
#   Size 32: 153 clusters
#   Size 33: 147 clusters
#   Size 34: 94 clusters
#   Size 35: 140 clusters
#   Size 36: 77 clusters
#   Size 37: 73 clusters
#   Size 38: 67 clusters
#   Size 39: 85 clusters
#   Size 40: 66 clusters
#   Size 41: 105 clusters
#   Size 42: 164 clusters
#   Size 43: 114 clusters
#   Size 44: 123 clusters
#   Size 45: 69 clusters
#   Size 46: 287 clusters
#   Size 47: 67 clusters
#   Size 48: 367 clusters
# Missing outlet warnings: 69954
# \n=== FINAL RESULTS (all_methods) ===
# Mean weighted frequency: 0.286
# Max weighted frequency: 1.314
# Non-zero frequency entries: 2352
# SURPRISAL WEIGHTING COMPARISON STATISTICS:
# Raw frequency matrix:
#   Mean: 0.4061
#   Std:  0.1342
#   Max:  0.8230
#   Non-zero entries: 2352
#
# Surprisal-weighted frequency matrix:
#   Mean: 0.2857
#   Std:  0.2027
#   Max:  1.3145
#   Non-zero entries: 2352
#
# Difference (weighted - raw):
#   Mean: -0.1204
#   Std:  0.1115
#   Range: [-0.2500, 0.5070]

# %%
# %%

# =============================================================================
# 6. HIERARCHICAL CLUSTERING AND ORDERING
# =============================================================================

# use analyzer method for hierarchical clustering
clustering_results = analyzer.analyze_hierarchical_clustering(frequency_matrix, COLORS)

# extract results for further use
ward_linkage = clustering_results['ward_linkage']
filtered_freq = clustering_results['filtered_freq']
ordered_freq = clustering_results['ordered_freq']
# Out:
# \n=== HIERARCHICAL CLUSTERING AND ORDERING ===

# %%
# %%

# =============================================================================
# 6.5. PER-COMMUNITY CONSISTENCY ANALYSIS
# =============================================================================

# use analyzer method for per-community consistency analysis
community_results = analyzer.analyze_per_community_consistency(ward_linkage, filtered_freq, COLORS)

# extract results for further use if needed
communities = community_results['communities']
community_stats = community_results['community_stats']
# Out:
# \n=== PER-COMMUNITY CONSISTENCY ANALYSIS ===
# Community structure from hierarchical clustering:
# \nCommunity 1 (10 outlets):
#   Outlets: rustavi2, reportiori, imedinews, postv, newspress, mpn, frontnews2, gttv, 1tv, tiflisnews
#   Within-community mean frequency: 0.651 ± 0.174
# \nCommunity 2 (14 outlets):
#   Outlets: ghn, alia, timer, mtavari, tvpirveli, sova, radiotavisupleba, accentnews, netgazeti, publika, on, tabula, formula, metronome
#   Within-community mean frequency: 0.403 ± 0.084
# \nCommunity 3 (6 outlets):
#   Outlets: palitravideo, metronome-mix, newsline, ambebi, kvirispalitra, allnews
#   Within-community mean frequency: 0.629 ± 0.141
# \nCommunity 4 (4 outlets):
#   Outlets: bm, bpn, batumelebi, itv
#   Within-community mean frequency: 0.542 ± 0.153
# \nCommunity 5 (4 outlets):
#   Outlets: amerikiskhma, euronewsgeorgia, civil, jamnews
#   Within-community mean frequency: 0.614 ± 0.145
# \nCommunity 6 (11 outlets):
#   Outlets: split, droni, altinfo, ipn, palitranews, tb24, agenda, mythdetector, paraleli, sputnik, primetime
#   Within-community mean frequency: 0.224 ± 0.079
# \nOverall pairwise frequency (all outlet pairs): 0.217
# \nCommunity coherence summary:
#   Most coherent: Community 1 (frequency: 0.651)
#   Least coherent: Community 6 (frequency: 0.224)
#   Higher frequency indicates more consistent clustering within community

# %%
# %%

# =============================================================================
# 7. CROSS-SAMPLE STATISTICAL SIGNIFICANCE TESTING
# =============================================================================

# %%
# %%

print("\\n=== SIGNIFICANCE ACROSS SAMPLES ANALYSIS ===")

# Apply the analyze_significance_across_samples method
try:
    across_samples_results = analyzer.analyze_significance_across_samples(
        alpha=0.05,
        min_sample_frac=0.5,
        test="wilcoxon"
    )
    
    # Extract results and set as primary significance results
    high_pairs = across_samples_results['high_pairs'] 
    low_pairs = across_samples_results['low_pairs']
    p_adj_matrix_samples = across_samples_results['p_adj_matrix']
    n_samples = across_samples_results['n_samples']
    masked_pairs_samples = across_samples_results['masked_pairs']
    significant_mask = (p_adj_matrix_samples < 0.05).values
    
    print(f"\\nACROSS-SAMPLES SIGNIFICANCE RESULTS:")
    print(f"Analyzed {n_samples} independent samples")
    print(f"High co-clustering pairs: {len(high_pairs)}")
    print(f"Low co-clustering pairs: {len(low_pairs)}")
    print(f"Masked pairs (insufficient coverage): {len(masked_pairs_samples)}")
    
    # Show significance mask visualization
    plt.figure(figsize=(8, 6))
    sns.heatmap(significant_mask.astype(int), cmap='RdBu_r', center=0.5, square=True,
                cbar_kws={'label': 'Significant (1) vs Non-significant (0)'},
                xticklabels=analyzer.outlet_names, yticklabels=analyzer.outlet_names)
    plt.title('Cross-Sample Statistical Significance', fontweight='bold')
    plt.tick_params(axis='both', labelsize=6)
    plt.tight_layout()
    plt.savefig('results/cross_sample_significance.png', dpi=300, bbox_inches='tight')
    plt.show()

    # -------------------------------------------------------------
    # effect size (observed – expected) matrix visualisation
    # -------------------------------------------------------------
    effect_matrix = across_samples_results.get('effect_matrix')
    if effect_matrix is not None:
        plt.figure(figsize=(8, 6))
        sns.heatmap(effect_matrix, cmap=DIVERGING_CMAP, center=0, square=True,
                    xticklabels=analyzer.outlet_names, yticklabels=analyzer.outlet_names,
                    cbar_kws={'label': 'observed – expected'})
        plt.title('Effect Size Matrix\n(Across-Sample Residual)', fontweight='bold')
        plt.tick_params(axis='both', labelsize=6)
        plt.tight_layout()
        plt.savefig('results/effect_size_matrix.png', dpi=300, bbox_inches='tight')
        plt.show()

except Exception as e:
    print(f"Cross-sample analysis failed: {e}")
    print("Cannot proceed without cross-sample significance results.")
    # Set empty results to prevent errors in downstream code
    high_pairs = []
    low_pairs = []
    significant_mask = np.zeros((len(analyzer.outlet_names), len(analyzer.outlet_names)), dtype=bool)
# Out:
# \n=== SIGNIFICANCE ACROSS SAMPLES ANALYSIS ===
#
# === SIGNIFICANCE ACROSS SAMPLES ===
# Processing 16 samples
# Processing sample win_00: 362 runs
# processing 362 clusterings for 49 outlets (sample_win_00)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_00) ===
# Surprisal weighting: enabled
# Total clusterings processed: 362
# Total weight sum: 130632.16
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.78
# Median surprisal weight: 0.57
# Cluster size distribution:
#   Size 1: 1590 clusters
#   Size 2: 228 clusters
#   Size 3: 139 clusters
#   Size 4: 117 clusters
#   Size 5: 119 clusters
#   Size 6: 95 clusters
#   Size 7: 68 clusters
#   Size 8: 64 clusters
#   Size 9: 80 clusters
#   Size 10: 63 clusters
#   Size 11: 70 clusters
#   Size 12: 50 clusters
#   Size 13: 47 clusters
#   Size 14: 36 clusters
#   Size 15: 22 clusters
#   Size 16: 12 clusters
#   Size 17: 15 clusters
#   Size 18: 9 clusters
#   Size 19: 15 clusters
#   Size 20: 16 clusters
#   Size 21: 10 clusters
#   Size 22: 6 clusters
#   Size 23: 7 clusters
#   Size 24: 6 clusters
#   Size 25: 9 clusters
#   Size 26: 5 clusters
#   Size 27: 15 clusters
#   Size 28: 12 clusters
#   Size 29: 6 clusters
#   Size 30: 9 clusters
#   Size 31: 5 clusters
#   Size 32: 11 clusters
#   Size 33: 18 clusters
#   Size 34: 4 clusters
#   Size 35: 3 clusters
#   Size 36: 7 clusters
#   Size 37: 4 clusters
#   Size 38: 3 clusters
#   Size 39: 5 clusters
#   Size 40: 6 clusters
#   Size 41: 3 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 45: 16 clusters
#   Size 46: 5 clusters
#   Size 47: 1 clusters
#   Size 48: 31 clusters
# Missing outlet warnings: 2610
# \n=== FINAL RESULTS (sample_win_00) ===
# Mean weighted frequency: 0.307
# Max weighted frequency: 1.596
# Non-zero frequency entries: 2352
# Processing sample win_01: 338 runs
# processing 338 clusterings for 49 outlets (sample_win_01)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_01) ===
# Surprisal weighting: enabled
# Total clusterings processed: 338
# Total weight sum: 137183.05
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 1.00
# Median surprisal weight: 0.86
# Cluster size distribution:
#   Size 1: 1414 clusters
#   Size 2: 162 clusters
#   Size 3: 106 clusters
#   Size 4: 132 clusters
#   Size 5: 147 clusters
#   Size 6: 99 clusters
#   Size 7: 66 clusters
#   Size 8: 52 clusters
#   Size 9: 50 clusters
#   Size 10: 112 clusters
#   Size 11: 64 clusters
#   Size 12: 64 clusters
#   Size 13: 29 clusters
#   Size 14: 16 clusters
#   Size 15: 14 clusters
#   Size 16: 27 clusters
#   Size 17: 32 clusters
#   Size 18: 12 clusters
#   Size 19: 5 clusters
#   Size 20: 15 clusters
#   Size 21: 11 clusters
#   Size 22: 24 clusters
#   Size 23: 14 clusters
#   Size 24: 12 clusters
#   Size 25: 16 clusters
#   Size 26: 27 clusters
#   Size 27: 8 clusters
#   Size 28: 10 clusters
#   Size 29: 11 clusters
#   Size 30: 8 clusters
#   Size 31: 5 clusters
#   Size 32: 7 clusters
#   Size 33: 3 clusters
#   Size 34: 2 clusters
#   Size 35: 2 clusters
#   Size 36: 1 clusters
#   Size 37: 4 clusters
#   Size 38: 5 clusters
#   Size 39: 11 clusters
#   Size 40: 2 clusters
#   Size 41: 3 clusters
#   Size 42: 1 clusters
#   Size 43: 2 clusters
#   Size 44: 1 clusters
#   Size 45: 2 clusters
#   Size 47: 3 clusters
#   Size 48: 15 clusters
# Missing outlet warnings: 2610
# \n=== FINAL RESULTS (sample_win_01) ===
# Mean weighted frequency: 0.345
# Max weighted frequency: 1.725
# Non-zero frequency entries: 2352
# Processing sample win_02: 330 runs
# processing 330 clusterings for 49 outlets (sample_win_02)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_02) ===
# Surprisal weighting: enabled
# Total clusterings processed: 330
# Total weight sum: 128384.04
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 1.01
# Median surprisal weight: 0.76
# Cluster size distribution:
#   Size 1: 1489 clusters
#   Size 2: 226 clusters
#   Size 3: 114 clusters
#   Size 4: 139 clusters
#   Size 5: 139 clusters
#   Size 6: 144 clusters
#   Size 7: 77 clusters
#   Size 8: 82 clusters
#   Size 9: 65 clusters
#   Size 10: 49 clusters
#   Size 11: 66 clusters
#   Size 12: 45 clusters
#   Size 13: 53 clusters
#   Size 14: 51 clusters
#   Size 15: 21 clusters
#   Size 16: 14 clusters
#   Size 17: 11 clusters
#   Size 18: 11 clusters
#   Size 19: 13 clusters
#   Size 20: 8 clusters
#   Size 21: 17 clusters
#   Size 22: 13 clusters
#   Size 23: 11 clusters
#   Size 24: 6 clusters
#   Size 25: 3 clusters
#   Size 26: 5 clusters
#   Size 27: 16 clusters
#   Size 28: 9 clusters
#   Size 29: 8 clusters
#   Size 30: 12 clusters
#   Size 31: 4 clusters
#   Size 32: 2 clusters
#   Size 34: 9 clusters
#   Size 35: 18 clusters
#   Size 36: 2 clusters
#   Size 37: 5 clusters
#   Size 38: 3 clusters
#   Size 40: 6 clusters
#   Size 41: 1 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 46: 5 clusters
#   Size 47: 4 clusters
#   Size 48: 13 clusters
# Missing outlet warnings: 3276
# \n=== FINAL RESULTS (sample_win_02) ===
# Mean weighted frequency: 0.331
# Max weighted frequency: 1.841
# Non-zero frequency entries: 2352
# Processing sample win_03: 398 runs
# processing 398 clusterings for 49 outlets (sample_win_03)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_03) ===
# Surprisal weighting: enabled
# Total clusterings processed: 398
# Total weight sum: 118023.67
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.57
# Median surprisal weight: 0.16
# Cluster size distribution:
#   Size 1: 2221 clusters
#   Size 2: 206 clusters
#   Size 3: 179 clusters
#   Size 4: 230 clusters
#   Size 5: 131 clusters
#   Size 6: 115 clusters
#   Size 7: 57 clusters
#   Size 8: 53 clusters
#   Size 9: 48 clusters
#   Size 10: 35 clusters
#   Size 11: 29 clusters
#   Size 12: 57 clusters
#   Size 13: 34 clusters
#   Size 14: 18 clusters
#   Size 15: 20 clusters
#   Size 16: 15 clusters
#   Size 17: 11 clusters
#   Size 18: 13 clusters
#   Size 19: 11 clusters
#   Size 20: 14 clusters
#   Size 21: 5 clusters
#   Size 22: 10 clusters
#   Size 23: 2 clusters
#   Size 24: 5 clusters
#   Size 25: 9 clusters
#   Size 26: 12 clusters
#   Size 27: 9 clusters
#   Size 28: 9 clusters
#   Size 29: 8 clusters
#   Size 30: 8 clusters
#   Size 31: 7 clusters
#   Size 32: 4 clusters
#   Size 33: 6 clusters
#   Size 34: 10 clusters
#   Size 35: 17 clusters
#   Size 36: 9 clusters
#   Size 37: 4 clusters
#   Size 38: 5 clusters
#   Size 39: 5 clusters
#   Size 40: 2 clusters
#   Size 41: 2 clusters
#   Size 42: 2 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 45: 13 clusters
#   Size 46: 2 clusters
#   Size 47: 27 clusters
#   Size 48: 53 clusters
# Missing outlet warnings: 5670
# \n=== FINAL RESULTS (sample_win_03) ===
# Mean weighted frequency: 0.252
# Max weighted frequency: 1.830
# Non-zero frequency entries: 2352
# Processing sample win_04: 401 runs
# processing 401 clusterings for 49 outlets (sample_win_04)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_04) ===
# Surprisal weighting: enabled
# Total clusterings processed: 401
# Total weight sum: 131010.69
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.62
# Median surprisal weight: 0.33
# Cluster size distribution:
#   Size 1: 1910 clusters
#   Size 2: 175 clusters
#   Size 3: 162 clusters
#   Size 4: 114 clusters
#   Size 5: 127 clusters
#   Size 6: 82 clusters
#   Size 7: 55 clusters
#   Size 8: 73 clusters
#   Size 9: 37 clusters
#   Size 10: 57 clusters
#   Size 11: 49 clusters
#   Size 12: 65 clusters
#   Size 13: 43 clusters
#   Size 14: 36 clusters
#   Size 15: 53 clusters
#   Size 16: 11 clusters
#   Size 17: 12 clusters
#   Size 18: 10 clusters
#   Size 19: 9 clusters
#   Size 20: 9 clusters
#   Size 21: 13 clusters
#   Size 22: 4 clusters
#   Size 23: 14 clusters
#   Size 24: 7 clusters
#   Size 25: 6 clusters
#   Size 26: 13 clusters
#   Size 27: 7 clusters
#   Size 28: 12 clusters
#   Size 29: 5 clusters
#   Size 30: 9 clusters
#   Size 31: 10 clusters
#   Size 32: 7 clusters
#   Size 33: 29 clusters
#   Size 34: 3 clusters
#   Size 35: 6 clusters
#   Size 36: 10 clusters
#   Size 37: 5 clusters
#   Size 38: 1 clusters
#   Size 39: 3 clusters
#   Size 40: 3 clusters
#   Size 41: 2 clusters
#   Size 44: 1 clusters
#   Size 46: 8 clusters
#   Size 47: 8 clusters
#   Size 48: 73 clusters
# Missing outlet warnings: 3486
# \n=== FINAL RESULTS (sample_win_04) ===
# Mean weighted frequency: 0.278
# Max weighted frequency: 1.461
# Non-zero frequency entries: 2352
# Processing sample win_05: 399 runs
# processing 399 clusterings for 49 outlets (sample_win_05)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_05) ===
# Surprisal weighting: enabled
# Total clusterings processed: 399
# Total weight sum: 128480.59
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.60
# Median surprisal weight: 0.29
# Cluster size distribution:
#   Size 1: 1831 clusters
#   Size 2: 201 clusters
#   Size 3: 149 clusters
#   Size 4: 128 clusters
#   Size 5: 150 clusters
#   Size 6: 108 clusters
#   Size 7: 69 clusters
#   Size 8: 52 clusters
#   Size 9: 44 clusters
#   Size 10: 55 clusters
#   Size 11: 37 clusters
#   Size 12: 33 clusters
#   Size 13: 26 clusters
#   Size 14: 27 clusters
#   Size 15: 41 clusters
#   Size 16: 22 clusters
#   Size 17: 18 clusters
#   Size 18: 11 clusters
#   Size 19: 4 clusters
#   Size 20: 12 clusters
#   Size 21: 7 clusters
#   Size 22: 20 clusters
#   Size 23: 19 clusters
#   Size 24: 9 clusters
#   Size 25: 17 clusters
#   Size 26: 8 clusters
#   Size 27: 9 clusters
#   Size 28: 8 clusters
#   Size 29: 2 clusters
#   Size 30: 5 clusters
#   Size 31: 11 clusters
#   Size 32: 8 clusters
#   Size 33: 23 clusters
#   Size 34: 7 clusters
#   Size 35: 8 clusters
#   Size 36: 5 clusters
#   Size 38: 4 clusters
#   Size 39: 7 clusters
#   Size 40: 4 clusters
#   Size 41: 3 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 2 clusters
#   Size 45: 3 clusters
#   Size 46: 7 clusters
#   Size 47: 6 clusters
#   Size 48: 73 clusters
# Missing outlet warnings: 3486
# \n=== FINAL RESULTS (sample_win_05) ===
# Mean weighted frequency: 0.274
# Max weighted frequency: 1.355
# Non-zero frequency entries: 2352
# Processing sample win_06: 401 runs
# processing 401 clusterings for 49 outlets (sample_win_06)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_06) ===
# Surprisal weighting: enabled
# Total clusterings processed: 401
# Total weight sum: 133334.83
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.63
# Median surprisal weight: 0.37
# Cluster size distribution:
#   Size 1: 1777 clusters
#   Size 2: 176 clusters
#   Size 3: 128 clusters
#   Size 4: 115 clusters
#   Size 5: 129 clusters
#   Size 6: 85 clusters
#   Size 7: 100 clusters
#   Size 8: 76 clusters
#   Size 9: 74 clusters
#   Size 10: 31 clusters
#   Size 11: 43 clusters
#   Size 12: 37 clusters
#   Size 13: 49 clusters
#   Size 14: 29 clusters
#   Size 15: 19 clusters
#   Size 16: 41 clusters
#   Size 17: 19 clusters
#   Size 18: 14 clusters
#   Size 19: 10 clusters
#   Size 20: 4 clusters
#   Size 21: 7 clusters
#   Size 22: 10 clusters
#   Size 23: 22 clusters
#   Size 24: 11 clusters
#   Size 25: 7 clusters
#   Size 26: 6 clusters
#   Size 27: 7 clusters
#   Size 28: 4 clusters
#   Size 29: 7 clusters
#   Size 30: 7 clusters
#   Size 31: 7 clusters
#   Size 32: 19 clusters
#   Size 33: 10 clusters
#   Size 34: 5 clusters
#   Size 35: 19 clusters
#   Size 36: 5 clusters
#   Size 37: 3 clusters
#   Size 38: 11 clusters
#   Size 39: 4 clusters
#   Size 40: 5 clusters
#   Size 41: 3 clusters
#   Size 42: 3 clusters
#   Size 44: 6 clusters
#   Size 45: 1 clusters
#   Size 46: 1 clusters
#   Size 47: 10 clusters
#   Size 48: 65 clusters
# Missing outlet warnings: 2610
# \n=== FINAL RESULTS (sample_win_06) ===
# Mean weighted frequency: 0.283
# Max weighted frequency: 1.599
# Non-zero frequency entries: 2352
# Processing sample win_07: 399 runs
# processing 399 clusterings for 49 outlets (sample_win_07)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_07) ===
# Surprisal weighting: enabled
# Total clusterings processed: 399
# Total weight sum: 140283.30
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.73
# Median surprisal weight: 0.49
# Cluster size distribution:
#   Size 1: 2078 clusters
#   Size 2: 186 clusters
#   Size 3: 157 clusters
#   Size 4: 93 clusters
#   Size 5: 134 clusters
#   Size 6: 104 clusters
#   Size 7: 104 clusters
#   Size 8: 84 clusters
#   Size 9: 45 clusters
#   Size 10: 50 clusters
#   Size 11: 63 clusters
#   Size 12: 34 clusters
#   Size 13: 64 clusters
#   Size 14: 44 clusters
#   Size 15: 21 clusters
#   Size 16: 5 clusters
#   Size 17: 16 clusters
#   Size 18: 12 clusters
#   Size 19: 10 clusters
#   Size 20: 7 clusters
#   Size 21: 13 clusters
#   Size 22: 15 clusters
#   Size 23: 9 clusters
#   Size 24: 15 clusters
#   Size 25: 5 clusters
#   Size 26: 8 clusters
#   Size 27: 9 clusters
#   Size 28: 13 clusters
#   Size 29: 4 clusters
#   Size 30: 7 clusters
#   Size 31: 15 clusters
#   Size 32: 35 clusters
#   Size 34: 8 clusters
#   Size 35: 10 clusters
#   Size 36: 9 clusters
#   Size 37: 3 clusters
#   Size 38: 1 clusters
#   Size 39: 4 clusters
#   Size 40: 2 clusters
#   Size 41: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 5 clusters
#   Size 44: 2 clusters
#   Size 45: 6 clusters
#   Size 46: 55 clusters
#   Size 48: 5 clusters
# Missing outlet warnings: 3276
# \n=== FINAL RESULTS (sample_win_07) ===
# Mean weighted frequency: 0.299
# Max weighted frequency: 1.510
# Non-zero frequency entries: 2352
# Processing sample win_08: 394 runs
# processing 394 clusterings for 49 outlets (sample_win_08)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_08) ===
# Surprisal weighting: enabled
# Total clusterings processed: 394
# Total weight sum: 131233.86
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.67
# Median surprisal weight: 0.33
# Cluster size distribution:
#   Size 1: 2171 clusters
#   Size 2: 175 clusters
#   Size 3: 174 clusters
#   Size 4: 78 clusters
#   Size 5: 125 clusters
#   Size 6: 94 clusters
#   Size 7: 68 clusters
#   Size 8: 50 clusters
#   Size 9: 66 clusters
#   Size 10: 68 clusters
#   Size 11: 93 clusters
#   Size 12: 22 clusters
#   Size 13: 52 clusters
#   Size 14: 26 clusters
#   Size 15: 19 clusters
#   Size 16: 11 clusters
#   Size 17: 10 clusters
#   Size 18: 15 clusters
#   Size 19: 11 clusters
#   Size 20: 11 clusters
#   Size 21: 16 clusters
#   Size 22: 2 clusters
#   Size 23: 13 clusters
#   Size 24: 7 clusters
#   Size 25: 10 clusters
#   Size 26: 16 clusters
#   Size 27: 11 clusters
#   Size 28: 5 clusters
#   Size 29: 9 clusters
#   Size 30: 6 clusters
#   Size 31: 12 clusters
#   Size 32: 11 clusters
#   Size 33: 12 clusters
#   Size 35: 14 clusters
#   Size 36: 3 clusters
#   Size 37: 2 clusters
#   Size 38: 5 clusters
#   Size 39: 6 clusters
#   Size 40: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 6 clusters
#   Size 45: 7 clusters
#   Size 46: 69 clusters
#   Size 47: 2 clusters
#   Size 48: 5 clusters
# Missing outlet warnings: 3888
# \n=== FINAL RESULTS (sample_win_08) ===
# Mean weighted frequency: 0.283
# Max weighted frequency: 1.418
# Non-zero frequency entries: 2352
# Processing sample win_09: 392 runs
# processing 392 clusterings for 49 outlets (sample_win_09)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_09) ===
# Surprisal weighting: enabled
# Total clusterings processed: 392
# Total weight sum: 124762.99
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.65
# Median surprisal weight: 0.29
# Cluster size distribution:
#   Size 1: 2338 clusters
#   Size 2: 195 clusters
#   Size 3: 223 clusters
#   Size 4: 155 clusters
#   Size 5: 150 clusters
#   Size 6: 97 clusters
#   Size 7: 64 clusters
#   Size 8: 45 clusters
#   Size 9: 49 clusters
#   Size 10: 49 clusters
#   Size 11: 74 clusters
#   Size 12: 51 clusters
#   Size 13: 22 clusters
#   Size 14: 33 clusters
#   Size 15: 9 clusters
#   Size 16: 12 clusters
#   Size 17: 7 clusters
#   Size 18: 8 clusters
#   Size 19: 10 clusters
#   Size 20: 16 clusters
#   Size 21: 21 clusters
#   Size 22: 9 clusters
#   Size 23: 5 clusters
#   Size 24: 11 clusters
#   Size 25: 19 clusters
#   Size 26: 5 clusters
#   Size 27: 9 clusters
#   Size 28: 11 clusters
#   Size 29: 2 clusters
#   Size 30: 5 clusters
#   Size 31: 2 clusters
#   Size 32: 8 clusters
#   Size 33: 7 clusters
#   Size 34: 20 clusters
#   Size 35: 8 clusters
#   Size 36: 5 clusters
#   Size 37: 3 clusters
#   Size 38: 4 clusters
#   Size 39: 2 clusters
#   Size 40: 4 clusters
#   Size 42: 1 clusters
#   Size 44: 6 clusters
#   Size 45: 7 clusters
#   Size 46: 69 clusters
#   Size 47: 1 clusters
#   Size 48: 6 clusters
# Missing outlet warnings: 5256
# \n=== FINAL RESULTS (sample_win_09) ===
# Mean weighted frequency: 0.271
# Max weighted frequency: 1.626
# Non-zero frequency entries: 2352
# Processing sample win_10: 396 runs
# processing 396 clusterings for 49 outlets (sample_win_10)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_10) ===
# Surprisal weighting: enabled
# Total clusterings processed: 396
# Total weight sum: 132645.71
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.71
# Median surprisal weight: 0.33
# Cluster size distribution:
#   Size 1: 2296 clusters
#   Size 2: 200 clusters
#   Size 3: 227 clusters
#   Size 4: 82 clusters
#   Size 5: 124 clusters
#   Size 6: 86 clusters
#   Size 7: 96 clusters
#   Size 8: 92 clusters
#   Size 9: 40 clusters
#   Size 10: 80 clusters
#   Size 11: 62 clusters
#   Size 12: 21 clusters
#   Size 13: 24 clusters
#   Size 14: 25 clusters
#   Size 15: 34 clusters
#   Size 16: 21 clusters
#   Size 17: 17 clusters
#   Size 18: 15 clusters
#   Size 19: 10 clusters
#   Size 20: 11 clusters
#   Size 21: 15 clusters
#   Size 22: 17 clusters
#   Size 23: 14 clusters
#   Size 24: 6 clusters
#   Size 25: 19 clusters
#   Size 26: 11 clusters
#   Size 27: 4 clusters
#   Size 28: 7 clusters
#   Size 29: 17 clusters
#   Size 30: 7 clusters
#   Size 31: 13 clusters
#   Size 32: 3 clusters
#   Size 33: 3 clusters
#   Size 34: 4 clusters
#   Size 35: 2 clusters
#   Size 36: 1 clusters
#   Size 37: 3 clusters
#   Size 38: 3 clusters
#   Size 39: 11 clusters
#   Size 40: 1 clusters
#   Size 41: 3 clusters
#   Size 43: 7 clusters
#   Size 45: 11 clusters
#   Size 46: 64 clusters
#   Size 48: 3 clusters
# Missing outlet warnings: 4620
# \n=== FINAL RESULTS (sample_win_10) ===
# Mean weighted frequency: 0.285
# Max weighted frequency: 1.380
# Non-zero frequency entries: 2352
# Processing sample win_11: 400 runs
# processing 400 clusterings for 49 outlets (sample_win_11)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_11) ===
# Surprisal weighting: enabled
# Total clusterings processed: 400
# Total weight sum: 128815.89
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.69
# Median surprisal weight: 0.29
# Cluster size distribution:
#   Size 1: 2797 clusters
#   Size 2: 207 clusters
#   Size 3: 174 clusters
#   Size 4: 130 clusters
#   Size 5: 141 clusters
#   Size 6: 139 clusters
#   Size 7: 69 clusters
#   Size 8: 113 clusters
#   Size 9: 52 clusters
#   Size 10: 39 clusters
#   Size 11: 31 clusters
#   Size 12: 17 clusters
#   Size 13: 38 clusters
#   Size 14: 25 clusters
#   Size 15: 19 clusters
#   Size 16: 15 clusters
#   Size 17: 11 clusters
#   Size 18: 12 clusters
#   Size 19: 11 clusters
#   Size 20: 9 clusters
#   Size 21: 17 clusters
#   Size 22: 6 clusters
#   Size 23: 9 clusters
#   Size 24: 5 clusters
#   Size 25: 9 clusters
#   Size 26: 10 clusters
#   Size 27: 6 clusters
#   Size 28: 11 clusters
#   Size 29: 14 clusters
#   Size 30: 18 clusters
#   Size 31: 13 clusters
#   Size 32: 3 clusters
#   Size 33: 3 clusters
#   Size 34: 4 clusters
#   Size 35: 5 clusters
#   Size 36: 6 clusters
#   Size 37: 2 clusters
#   Size 38: 7 clusters
#   Size 39: 3 clusters
#   Size 40: 3 clusters
#   Size 41: 10 clusters
#   Size 42: 6 clusters
#   Size 43: 11 clusters
#   Size 44: 65 clusters
#   Size 47: 1 clusters
#   Size 48: 5 clusters
# Missing outlet warnings: 5538
# \n=== FINAL RESULTS (sample_win_11) ===
# Mean weighted frequency: 0.274
# Max weighted frequency: 1.434
# Non-zero frequency entries: 2352
# Processing sample win_12: 396 runs
# processing 396 clusterings for 49 outlets (sample_win_12)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_12) ===
# Surprisal weighting: enabled
# Total clusterings processed: 396
# Total weight sum: 124966.84
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.68
# Median surprisal weight: 0.26
# Cluster size distribution:
#   Size 1: 3241 clusters
#   Size 2: 184 clusters
#   Size 3: 129 clusters
#   Size 4: 112 clusters
#   Size 5: 140 clusters
#   Size 6: 118 clusters
#   Size 7: 99 clusters
#   Size 8: 41 clusters
#   Size 9: 44 clusters
#   Size 10: 50 clusters
#   Size 11: 27 clusters
#   Size 12: 29 clusters
#   Size 13: 27 clusters
#   Size 14: 23 clusters
#   Size 15: 25 clusters
#   Size 16: 16 clusters
#   Size 17: 11 clusters
#   Size 18: 8 clusters
#   Size 19: 16 clusters
#   Size 20: 12 clusters
#   Size 21: 16 clusters
#   Size 22: 10 clusters
#   Size 23: 7 clusters
#   Size 24: 11 clusters
#   Size 25: 9 clusters
#   Size 26: 8 clusters
#   Size 27: 7 clusters
#   Size 28: 14 clusters
#   Size 29: 8 clusters
#   Size 30: 15 clusters
#   Size 31: 7 clusters
#   Size 32: 9 clusters
#   Size 33: 5 clusters
#   Size 34: 1 clusters
#   Size 35: 2 clusters
#   Size 37: 3 clusters
#   Size 38: 6 clusters
#   Size 39: 5 clusters
#   Size 40: 3 clusters
#   Size 41: 6 clusters
#   Size 42: 14 clusters
#   Size 43: 72 clusters
#   Size 44: 4 clusters
#   Size 45: 1 clusters
#   Size 46: 1 clusters
#   Size 47: 1 clusters
#   Size 48: 5 clusters
# Missing outlet warnings: 6660
# \n=== FINAL RESULTS (sample_win_12) ===
# Mean weighted frequency: 0.268
# Max weighted frequency: 1.399
# Non-zero frequency entries: 2352
# Processing sample win_13: 396 runs
# processing 396 clusterings for 49 outlets (sample_win_13)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_13) ===
# Surprisal weighting: enabled
# Total clusterings processed: 396
# Total weight sum: 123894.16
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.64
# Median surprisal weight: 0.33
# Cluster size distribution:
#   Size 1: 3005 clusters
#   Size 2: 229 clusters
#   Size 3: 186 clusters
#   Size 4: 129 clusters
#   Size 5: 148 clusters
#   Size 6: 78 clusters
#   Size 7: 60 clusters
#   Size 8: 58 clusters
#   Size 9: 30 clusters
#   Size 10: 81 clusters
#   Size 11: 28 clusters
#   Size 12: 27 clusters
#   Size 13: 23 clusters
#   Size 14: 16 clusters
#   Size 15: 12 clusters
#   Size 16: 13 clusters
#   Size 17: 18 clusters
#   Size 18: 5 clusters
#   Size 19: 9 clusters
#   Size 20: 10 clusters
#   Size 21: 5 clusters
#   Size 22: 13 clusters
#   Size 23: 8 clusters
#   Size 24: 8 clusters
#   Size 25: 11 clusters
#   Size 26: 4 clusters
#   Size 27: 8 clusters
#   Size 28: 4 clusters
#   Size 29: 9 clusters
#   Size 30: 13 clusters
#   Size 31: 13 clusters
#   Size 32: 10 clusters
#   Size 33: 8 clusters
#   Size 34: 7 clusters
#   Size 35: 4 clusters
#   Size 36: 4 clusters
#   Size 37: 16 clusters
#   Size 38: 6 clusters
#   Size 39: 8 clusters
#   Size 40: 7 clusters
#   Size 41: 30 clusters
#   Size 42: 18 clusters
#   Size 43: 12 clusters
#   Size 44: 27 clusters
#   Size 46: 1 clusters
#   Size 47: 3 clusters
#   Size 48: 6 clusters
# Missing outlet warnings: 5916
# \n=== FINAL RESULTS (sample_win_13) ===
# Mean weighted frequency: 0.266
# Max weighted frequency: 1.421
# Non-zero frequency entries: 2352
# Processing sample win_14: 394 runs
# processing 394 clusterings for 49 outlets (sample_win_14)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_14) ===
# Surprisal weighting: enabled
# Total clusterings processed: 394
# Total weight sum: 133312.94
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.77
# Median surprisal weight: 0.33
# Cluster size distribution:
#   Size 1: 3000 clusters
#   Size 2: 164 clusters
#   Size 3: 150 clusters
#   Size 4: 99 clusters
#   Size 5: 168 clusters
#   Size 6: 86 clusters
#   Size 7: 124 clusters
#   Size 8: 57 clusters
#   Size 9: 57 clusters
#   Size 10: 52 clusters
#   Size 11: 39 clusters
#   Size 12: 27 clusters
#   Size 13: 19 clusters
#   Size 14: 61 clusters
#   Size 15: 19 clusters
#   Size 16: 15 clusters
#   Size 17: 20 clusters
#   Size 18: 5 clusters
#   Size 19: 11 clusters
#   Size 20: 12 clusters
#   Size 21: 18 clusters
#   Size 22: 18 clusters
#   Size 23: 7 clusters
#   Size 24: 15 clusters
#   Size 25: 10 clusters
#   Size 26: 8 clusters
#   Size 27: 3 clusters
#   Size 28: 5 clusters
#   Size 29: 7 clusters
#   Size 30: 4 clusters
#   Size 31: 12 clusters
#   Size 32: 7 clusters
#   Size 33: 9 clusters
#   Size 34: 2 clusters
#   Size 35: 7 clusters
#   Size 36: 1 clusters
#   Size 37: 5 clusters
#   Size 38: 1 clusters
#   Size 39: 2 clusters
#   Size 40: 12 clusters
#   Size 41: 10 clusters
#   Size 42: 71 clusters
#   Size 44: 1 clusters
#   Size 45: 1 clusters
#   Size 48: 4 clusters
# Missing outlet warnings: 5796
# \n=== FINAL RESULTS (sample_win_14) ===
# Mean weighted frequency: 0.288
# Max weighted frequency: 1.534
# Non-zero frequency entries: 2352
# Processing sample win_15: 395 runs
# processing 395 clusterings for 49 outlets (sample_win_15)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (sample_win_15) ===
# Surprisal weighting: enabled
# Total clusterings processed: 395
# Total weight sum: 132988.23
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.76
# Median surprisal weight: 0.44
# Cluster size distribution:
#   Size 1: 2927 clusters
#   Size 2: 165 clusters
#   Size 3: 114 clusters
#   Size 4: 141 clusters
#   Size 5: 211 clusters
#   Size 6: 108 clusters
#   Size 7: 110 clusters
#   Size 8: 119 clusters
#   Size 9: 56 clusters
#   Size 10: 21 clusters
#   Size 11: 29 clusters
#   Size 12: 19 clusters
#   Size 13: 23 clusters
#   Size 14: 17 clusters
#   Size 15: 10 clusters
#   Size 16: 20 clusters
#   Size 17: 17 clusters
#   Size 18: 3 clusters
#   Size 19: 8 clusters
#   Size 20: 23 clusters
#   Size 21: 12 clusters
#   Size 22: 17 clusters
#   Size 23: 8 clusters
#   Size 24: 13 clusters
#   Size 25: 10 clusters
#   Size 26: 12 clusters
#   Size 27: 4 clusters
#   Size 28: 5 clusters
#   Size 29: 8 clusters
#   Size 30: 7 clusters
#   Size 31: 2 clusters
#   Size 32: 9 clusters
#   Size 33: 11 clusters
#   Size 34: 8 clusters
#   Size 35: 15 clusters
#   Size 36: 9 clusters
#   Size 37: 11 clusters
#   Size 38: 2 clusters
#   Size 39: 9 clusters
#   Size 40: 4 clusters
#   Size 41: 27 clusters
#   Size 42: 43 clusters
#   Size 45: 1 clusters
#   Size 48: 5 clusters
# Missing outlet warnings: 5256
# \n=== FINAL RESULTS (sample_win_15) ===
# Mean weighted frequency: 0.286
# Max weighted frequency: 1.570
# Non-zero frequency entries: 2352
# Stacked 16 sample matrices, shape: (16, 49, 49)
# Computing null for sample win_00: 362 runs
# Computing null for sample win_01: 338 runs
# Computing null for sample win_02: 330 runs
# Computing null for sample win_03: 398 runs
# Computing null for sample win_04: 401 runs
# Computing null for sample win_05: 399 runs
# Computing null for sample win_06: 401 runs
# Computing null for sample win_07: 399 runs
# Computing null for sample win_08: 394 runs
# Computing null for sample win_09: 392 runs
# Computing null for sample win_10: 396 runs
# Computing null for sample win_11: 400 runs
# Computing null for sample win_12: 396 runs
# Computing null for sample win_13: 396 runs
# Computing null for sample win_14: 394 runs
# Computing null for sample win_15: 395 runs
# Testable pairs: 1176, Masked pairs: 0
# Using wilcoxon test for 16 samples
# FDR correction: 845/1176 pairs significant
#
# RESULTS SUMMARY:
# Samples analysed: 16
# Significantly HIGH pairs: 251
# Significantly LOW  pairs: 594
# Masked pairs: 0
# \nACROSS-SAMPLES SIGNIFICANCE RESULTS:
# Analyzed 16 independent samples
# High co-clustering pairs: 251
# Low co-clustering pairs: 594
# Masked pairs (insufficient coverage): 0

# %%
# %%

# =============================================================================
# 7.2. VALIDATED CLUSTERING FROM CROSS-SAMPLE SIGNIFICANCE
# =============================================================================

print("\n=== VALIDATED CLUSTERING (cross-sample significant edges) ===")

validated_across = analyzer.construct_validated_clustering(
    high_pairs=high_pairs,
    low_pairs=low_pairs,
    null_mean=0.0,  # baseline similarity for non-validated pairs
    null_std=0.0,
    n_clusters=None,
)

if validated_across and 'labels' in validated_across:
    Z_valid = validated_across['linkage']
    communities_valid = validated_across['communities']
    dist_valid = validated_across['distance_matrix']
    sim_valid = validated_across.get('similarity_matrix')

    print(f"\nConstructed {len(communities_valid)} validated communities (cross-sample):")
    for cid, members in sorted(communities_valid.items()):
        print(f"  Community {cid} ({len(members)} outlets): {', '.join(members)}")

    # visualise dendrogram + ordered distance heatmap
    try:
        order = leaves_list(Z_valid)
        ordered_dist = pd.DataFrame(dist_valid, index=analyzer.outlet_names,
                                    columns=analyzer.outlet_names).iloc[order, order]

        cmap_signed = LinearSegmentedColormap.from_list('signed_cmap',
                                                        ['#2E86AB', '#F7F7F7', '#C73E1D'], N=256)

        fig, axes = plt.subplots(1, 2, figsize=(16, 6))

        sns.heatmap(ordered_dist, cmap=cmap_signed, square=True, ax=axes[0],
                    cbar_kws={'label': 'signed distance'})
        axes[0].set_title('Signed Distance Matrix (validated edges)')
        axes[0].tick_params(axis='both', labelsize=6)

        dendrogram(Z_valid, labels=[analyzer.outlet_names[i] for i in order],
                    orientation='right', leaf_font_size=6, ax=axes[1])
        axes[1].set_title('Hierarchical Clustering\n(validated edges)')

        plt.tight_layout()
        os.makedirs('results', exist_ok=True)
        plt.savefig('results/final_validated_consensus_signed.png', dpi=300, bbox_inches='tight')
        plt.show()
    except Exception as e:
        print(f"Visualisation failed: {e}")

    # ---------------------------------------------------------
    # 7.2.aA  Graph visualisation – strongest validated edges
    # ---------------------------------------------------------
    try:
        if sim_valid is not None:
            # determine threshold for strongest edges (top 5% of all off-diagonal similarities)
            triu_idx = np.triu_indices_from(sim_valid, k=1)
            sim_vals = sim_valid[triu_idx]
            # consider only positive similarities for thresholding to avoid diluting with low/negative values
            sim_vals_pos = sim_vals[sim_vals > 0]

            if sim_vals_pos.size > 0:
                threshold = np.percentile(sim_vals_pos, 75)
            else:
                threshold = None

            # if threshold yields too few edges, iteratively relax criterion
            n_out = len(analyzer.outlet_names)
            min_edges_target = max(10, n_out // 2)  # aim for at least this many edges
            if threshold is not None:
                for pct in [85, 80, 75, 70]:
                    # quick check without building full graph yet
                    if np.sum(sim_vals_pos >= threshold) >= min_edges_target:
                        break
                    threshold = np.percentile(sim_vals_pos, pct)

            # build graph with only strong edges
            G_strong = nx.Graph()
            label_map = {outlet: cid for cid, members in communities_valid.items() for outlet in members}

            # add nodes with community metadata
            for outlet in analyzer.outlet_names:
                G_strong.add_node(outlet, community=label_map.get(outlet, -1))

            # add edges above threshold
            if threshold is not None:
                for i in range(n_out):
                    for j in range(i + 1, n_out):
                        w = sim_valid[i, j]
                        if w >= threshold:
                            G_strong.add_edge(analyzer.outlet_names[i], analyzer.outlet_names[j], weight=w)

            # skip visualisation if graph has no edges
            if G_strong.number_of_edges() > 0:
                fig, ax_graph = plt.subplots(figsize=(10, 8))

                # layout – spring layout seeded for reproducibility
                pos = nx.spring_layout(G_strong, seed=42, k=0.3)

                # node colors by community
                palette = sns.color_palette("tab10", n_colors=max(communities_valid.keys()))
                node_colors = [palette[label_map.get(node, 0)-1] if label_map.get(node, 0) > 0 else (0.7, 0.7, 0.7) for node in G_strong.nodes()]

                # edge colors scaled by weight
                edge_weights = [G_strong[u][v]['weight'] for u, v in G_strong.edges()]
                if edge_weights:
                    norm = plt.Normalize(min(edge_weights), max(edge_weights))
                    edge_colors = [plt.cm.Blues(norm(w)) for w in edge_weights]
                else:
                    edge_colors = 'grey'

                nx.draw_networkx_nodes(G_strong, pos, node_color=node_colors, node_size=350, edgecolors='black', linewidths=0.5, ax=ax_graph)
                nx.draw_networkx_edges(G_strong, pos, edge_color=edge_colors, width=2, ax=ax_graph)
                nx.draw_networkx_labels(G_strong, pos, font_size=8, ax=ax_graph)

                # colour bar for edge weights, if edges exist
                if edge_weights:
                    sm = plt.cm.ScalarMappable(cmap='Blues', norm=norm)
                    sm.set_array([])
                    fig.colorbar(sm, ax=ax_graph, label='co-clustering similarity')

                ax_graph.set_axis_off()
                ax_graph.set_title('Validated Communities – Strongest 25% Edges', fontweight='bold')
                fig.tight_layout()
                fig.savefig('results/final_validated_consensus_graph.png', dpi=300, bbox_inches='tight')
                plt.show()
            else:
                print("  No edges exceed the strength threshold – graph not displayed")
    except Exception as e:
        print(f"  Graph visualisation failed: {e}")

    # ---------------------------------------------------------
    # 7.2.aB  Consensus statistics (within / between IPA)
    # ---------------------------------------------------------
    if sim_valid is not None:
        n_out = len(analyzer.outlet_names)
        label_map = {}
        for cid, members in communities_valid.items():
            for m in members:
                label_map[m] = cid

        within_vals = []
        between_vals = []
        for i in range(n_out):
            for j in range(i + 1, n_out):
                val = sim_valid[i, j] if isinstance(sim_valid, np.ndarray) else sim_valid.iloc[i, j]
                if label_map[analyzer.outlet_names[i]] == label_map[analyzer.outlet_names[j]]:
                    within_vals.append(val)
                else:
                    between_vals.append(val)

        if within_vals and between_vals:
            w_median = np.median(within_vals)
            w_q1, w_q3 = np.percentile(within_vals, [25, 75])
            b_median = np.median(between_vals)
            print("\nConsensus similarity statistics:")
            print(f"  Median within-community IPA: {w_median:.3f} (IQR {w_q1:.3f}–{w_q3:.3f})")
            print(f"  Median between-community IPA: {b_median:.3f}")

    # ---------------------------------------------------------
    # 7.2.b  Signed modularity of validated graph
    # ---------------------------------------------------------
    try:
        sim_pos = np.clip(sim_valid, 0, None) if sim_valid is not None else None
        if sim_pos is not None:
            G_mod = nx.from_numpy_array(sim_pos)
            partition = [set() for _ in communities_valid]
            for cid, members in communities_valid.items():
                for outlet in members:
                    idx = analyzer.outlet_names.index(outlet)
                    partition[cid-1].add(idx)
            partition = [p for p in partition if p]
            if len(partition) > 1:
                Q_signed = nx.community.modularity(G_mod, partition, weight='weight')
                print(f"  Signed modularity Q: {Q_signed:.3f}")
    except Exception as e:
        print(f"  Modularity calculation failed: {e}")

    # ---------------------------------------------------------
    # 7.2.c  Elbow criterion – suggest k*
    # ---------------------------------------------------------
    try:
        distances = Z_valid[:, 2]
        diffs = np.diff(distances, prepend=distances[0])
        elbow_idx = np.argmax(diffs)
        k_star = len(analyzer.outlet_names) - elbow_idx
        print(f"  Elbow criterion suggests k* = {k_star}")
    except Exception as e:
        print(f"  Elbow analysis failed: {e}")

else:
    print("No validated clustering could be constructed (no significant edges)")
# Out:
# === VALIDATED CLUSTERING (cross-sample significant edges) ===
# \n=== CONSTRUCTING VALIDATED CLUSTERING ===
# Constructed signed similarity matrix using 251 high and 594 low pairs
# Successfully constructed 6 validated communities
#
# Constructed 6 validated communities (cross-sample):
#   Community 1 (10 outlets): 1tv, newspress, imedinews, rustavi2, tiflisnews, mpn, gttv, postv, frontnews2, reportiori
#   Community 2 (14 outlets): mtavari, ghn, alia, timer, sova, tvpirveli, formula, netgazeti, radiotavisupleba, on, metronome, publika, accentnews, tabula
#   Community 3 (7 outlets): metronome-mix, newsline, palitravideo, primetime, kvirispalitra, ambebi, allnews
#   Community 4 (4 outlets): euronewsgeorgia, civil, jamnews, amerikiskhma
#   Community 5 (4 outlets): bm, bpn, batumelebi, itv
#   Community 6 (10 outlets): ipn, palitranews, mythdetector, sputnik, paraleli, tb24, droni, agenda, split, altinfo
# Consensus similarity statistics:
#   Median within-community IPA: 0.571 (IQR 0.395–0.707)
#   Median between-community IPA: 0.126
#   Signed modularity Q: 0.343
#   Elbow criterion suggests k* = 2

# %%
# %%

# =============================================================================
# 8. PER-METHOD SURPRISAL-WEIGHTED CO-CLUSTERING ANALYSIS
# =============================================================================

print("\\n=== PER-METHOD SURPRISAL-WEIGHTED CO-CLUSTERING ANALYSIS ===")

# get aggregated results for each individual method
method_results = analyzer.aggregate_results_by_method_with_surprisal()

if method_results:
    print(f"Analyzing {len(method_results)} individual methods...")

    # -------------------------------------------------------------
    # 8.a Correlation of each method with final consensus matrix
    # -------------------------------------------------------------
    consensus_flat = frequency_matrix_weighted.values[off_diag_mask]
    method_corrs = {}
    for m_name, m_mat in method_results.items():
        vals = m_mat.values[off_diag_mask]
        if vals.std() == 0:
            corr = 0.0
        else:
            corr = np.corrcoef(consensus_flat, vals)[0, 1]
        method_corrs[m_name] = corr

    # rank methods
    ranked_methods = sorted(method_corrs.items(), key=lambda x: x[1], reverse=True)
    print("\nCorrelation of individual methods with final consensus (top 10):")
    for m, r in ranked_methods[:10]:
        print(f"  {m}: r = {r:.3f}")

    # identify lowest-contributing third
    n_methods_total = len(ranked_methods)
    n_remove = max(1, n_methods_total // 3)
    low_methods = [m for m, _ in ranked_methods[-n_remove:]]
    print(f"\nRemoving lowest-contributing {n_remove} methods: {', '.join(low_methods)}")

    # aggregate remaining methods by simple mean
    remaining_mats = [mat.values for name, mat in method_results.items() if name not in low_methods]
    remaining_avg = np.mean(remaining_mats, axis=0)
    remaining_avg_df = pd.DataFrame(remaining_avg, index=analyzer.outlet_names, columns=analyzer.outlet_names)

    # hierarchical clustering of remaining
    rem_dist = remaining_avg_df.values.max() - remaining_avg_df.values
    rem_link = linkage(squareform(rem_dist, checks=False), method='ward')
    if validated_across and 'labels' in validated_across:
        original_labels = validated_across['labels']
        # choose same number of clusters
        n_clusters_consensus = validated_across['n_clusters']
        rem_labels = fcluster(rem_link, n_clusters_consensus, criterion='maxclust')
        try:
            from sklearn.metrics import adjusted_rand_score
            delta_ari = adjusted_rand_score(original_labels, rem_labels)
            print(f"\nPartition similarity after removal (ARI): {delta_ari:.3f}")
        except Exception as e:
            print(f"Could not compute ARI after method removal: {e}")
    
    # save correlation matrix figure
    method_comp = analyzer.compare_method_coclustering(method_results)
else:
    print("No method results to analyze")
# Out:
# \n=== PER-METHOD SURPRISAL-WEIGHTED CO-CLUSTERING ANALYSIS ===
# \n=== AGGREGATING RESULTS BY METHOD WITH SURPRISAL WEIGHTING ===
# aggregating 16 results for conditional_probability_girvan_newman_params_0
# processing 16 clusterings for 49 outlets (conditional_probability_girvan_newman_params_0)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_girvan_newman_params_0) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 1800.69
# Surprisal weight range: 0.03 to 0.26
# Mean surprisal weight: 0.11
# Median surprisal weight: 0.12
# Cluster size distribution:
#   Size 1: 62 clusters
#   Size 41: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 2 clusters
#   Size 45: 4 clusters
#   Size 47: 4 clusters
#   Size 48: 3 clusters
# \n=== FINAL RESULTS (conditional_probability_girvan_newman_params_0) ===
# Mean weighted frequency: 0.096
# Max weighted frequency: 0.121
# Non-zero frequency entries: 2352
# aggregating 13 results for conditional_probability_k_cores_params_0
# processing 13 clusterings for 49 outlets (conditional_probability_k_cores_params_0)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_k_cores_params_0) ===
# Surprisal weighting: enabled
# Total clusterings processed: 13
# Total weight sum: 1636.05
# Surprisal weight range: 0.03 to 4.03
# Mean surprisal weight: 0.12
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 4 clusters
#   Size 3: 4 clusters
#   Size 5: 2 clusters
#   Size 6: 1 clusters
#   Size 7: 2 clusters
#   Size 42: 2 clusters
#   Size 43: 1 clusters
#   Size 44: 2 clusters
#   Size 46: 4 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_k_cores_params_0) ===
# Mean weighted frequency: 0.111
# Max weighted frequency: 2.411
# Non-zero frequency entries: 2270
# aggregating 13 results for conditional_probability_k_cores_params_1
# processing 13 clusterings for 49 outlets (conditional_probability_k_cores_params_1)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_k_cores_params_1) ===
# Surprisal weighting: enabled
# Total clusterings processed: 13
# Total weight sum: 1671.84
# Surprisal weight range: 0.03 to 4.03
# Mean surprisal weight: 0.13
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 4 clusters
#   Size 3: 4 clusters
#   Size 5: 1 clusters
#   Size 6: 2 clusters
#   Size 7: 2 clusters
#   Size 42: 2 clusters
#   Size 43: 2 clusters
#   Size 44: 1 clusters
#   Size 46: 4 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_k_cores_params_1) ===
# Mean weighted frequency: 0.113
# Max weighted frequency: 2.400
# Non-zero frequency entries: 2270
# aggregating 13 results for conditional_probability_k_cores_params_2
# processing 13 clusterings for 49 outlets (conditional_probability_k_cores_params_2)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_k_cores_params_2) ===
# Surprisal weighting: enabled
# Total clusterings processed: 13
# Total weight sum: 1706.67
# Surprisal weight range: 0.03 to 4.03
# Mean surprisal weight: 0.13
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 4 clusters
#   Size 3: 4 clusters
#   Size 5: 1 clusters
#   Size 6: 1 clusters
#   Size 7: 3 clusters
#   Size 42: 3 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 46: 4 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_k_cores_params_2) ===
# Mean weighted frequency: 0.116
# Max weighted frequency: 2.383
# Non-zero frequency entries: 2272
# aggregating 14 results for conditional_probability_k_cores_params_3
# processing 14 clusterings for 49 outlets (conditional_probability_k_cores_params_3)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_k_cores_params_3) ===
# Surprisal weighting: enabled
# Total clusterings processed: 14
# Total weight sum: 1776.27
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.12
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 4 clusters
#   Size 2: 1 clusters
#   Size 3: 4 clusters
#   Size 5: 1 clusters
#   Size 6: 1 clusters
#   Size 7: 3 clusters
#   Size 42: 3 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 46: 4 clusters
#   Size 47: 1 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_k_cores_params_3) ===
# Mean weighted frequency: 0.108
# Max weighted frequency: 2.217
# Non-zero frequency entries: 2352
# aggregating 14 results for conditional_probability_k_cores_params_4
# processing 14 clusterings for 49 outlets (conditional_probability_k_cores_params_4)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_k_cores_params_4) ===
# Surprisal weighting: enabled
# Total clusterings processed: 14
# Total weight sum: 1843.56
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.13
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 4 clusters
#   Size 2: 1 clusters
#   Size 3: 4 clusters
#   Size 5: 1 clusters
#   Size 6: 1 clusters
#   Size 7: 1 clusters
#   Size 8: 2 clusters
#   Size 41: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 46: 4 clusters
#   Size 47: 1 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_k_cores_params_4) ===
# Mean weighted frequency: 0.112
# Max weighted frequency: 2.190
# Non-zero frequency entries: 2352
# aggregating 13 results for conditional_probability_label_propagation_params_0
# processing 13 clusterings for 49 outlets (conditional_probability_label_propagation_params_0)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_label_propagation_params_0) ===
# Surprisal weighting: enabled
# Total clusterings processed: 13
# Total weight sum: 1358.48
# Surprisal weight range: 0.03 to 0.22
# Mean surprisal weight: 0.10
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 46 clusters
#   Size 42: 2 clusters
#   Size 43: 1 clusters
#   Size 44: 2 clusters
#   Size 46: 4 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_label_propagation_params_0) ===
# Mean weighted frequency: 0.093
# Max weighted frequency: 0.110
# Non-zero frequency entries: 2256
# aggregating 16 results for conditional_probability_leiden_params_0
# processing 16 clusterings for 49 outlets (conditional_probability_leiden_params_0)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_leiden_params_0) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 8602.92
# Surprisal weight range: 0.61 to 4.03
# Mean surprisal weight: 1.21
# Median surprisal weight: 1.22
# Cluster size distribution:
#   Size 1: 46 clusters
#   Size 3: 1 clusters
#   Size 4: 1 clusters
#   Size 5: 1 clusters
#   Size 9: 1 clusters
#   Size 10: 2 clusters
#   Size 12: 3 clusters
#   Size 14: 2 clusters
#   Size 15: 1 clusters
#   Size 16: 2 clusters
#   Size 17: 3 clusters
#   Size 18: 2 clusters
#   Size 19: 2 clusters
#   Size 20: 3 clusters
#   Size 21: 7 clusters
#   Size 22: 2 clusters
#   Size 23: 1 clusters
#   Size 24: 1 clusters
#   Size 25: 3 clusters
#   Size 26: 1 clusters
#   Size 30: 1 clusters
#   Size 32: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_leiden_params_0) ===
# Mean weighted frequency: 0.463
# Max weighted frequency: 1.321
# Non-zero frequency entries: 2322
# aggregating 13 results for conditional_probability_leiden_params_1
# processing 13 clusterings for 49 outlets (conditional_probability_leiden_params_1)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_leiden_params_1) ===
# Surprisal weighting: enabled
# Total clusterings processed: 13
# Total weight sum: 1358.48
# Surprisal weight range: 0.03 to 0.22
# Mean surprisal weight: 0.10
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 46 clusters
#   Size 42: 2 clusters
#   Size 43: 1 clusters
#   Size 44: 2 clusters
#   Size 46: 4 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_leiden_params_1) ===
# Mean weighted frequency: 0.093
# Max weighted frequency: 0.110
# Non-zero frequency entries: 2256
# aggregating 13 results for conditional_probability_leiden_params_2
# processing 13 clusterings for 49 outlets (conditional_probability_leiden_params_2)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_leiden_params_2) ===
# Surprisal weighting: enabled
# Total clusterings processed: 13
# Total weight sum: 1403.07
# Surprisal weight range: 0.03 to 0.22
# Mean surprisal weight: 0.11
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 48 clusters
#   Size 42: 3 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 46: 4 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_leiden_params_2) ===
# Mean weighted frequency: 0.096
# Max weighted frequency: 0.115
# Non-zero frequency entries: 2256
# aggregating 14 results for conditional_probability_leiden_params_3
# processing 14 clusterings for 49 outlets (conditional_probability_leiden_params_3)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_leiden_params_3) ===
# Surprisal weighting: enabled
# Total clusterings processed: 14
# Total weight sum: 1506.84
# Surprisal weight range: 0.03 to 0.26
# Mean surprisal weight: 0.11
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 52 clusters
#   Size 41: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 46: 4 clusters
#   Size 47: 1 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_leiden_params_3) ===
# Mean weighted frequency: 0.092
# Max weighted frequency: 0.116
# Non-zero frequency entries: 2350
# aggregating 14 results for conditional_probability_leiden_params_4
# processing 14 clusterings for 49 outlets (conditional_probability_leiden_params_4)
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 48 clusters
#   Size 42: 3 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 46: 4 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_leiden_params_2) ===
# Mean weighted frequency: 0.096
# Max weighted frequency: 0.115
# Non-zero frequency entries: 2256
# aggregating 14 results for conditional_probability_leiden_params_3
# processing 14 clusterings for 49 outlets (conditional_probability_leiden_params_3)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_leiden_params_3) ===
# Surprisal weighting: enabled
# Total clusterings processed: 14
# Total weight sum: 1506.84
# Surprisal weight range: 0.03 to 0.26
# Mean surprisal weight: 0.11
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 52 clusters
#   Size 41: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
#   Size 44: 1 clusters
#   Size 46: 4 clusters
#   Size 47: 1 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_leiden_params_3) ===
# Mean weighted frequency: 0.092
# Max weighted frequency: 0.116
# Non-zero frequency entries: 2350
# aggregating 14 results for conditional_probability_leiden_params_4
# processing 14 clusterings for 49 outlets (conditional_probability_leiden_params_4)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_leiden_params_4) ===
# Surprisal weighting: enabled
# Total clusterings processed: 14
# Total weight sum: 1610.15
# Surprisal weight range: 0.03 to 0.26
# Mean surprisal weight: 0.12
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 56 clusters
#   Size 41: 2 clusters
#   Size 42: 2 clusters
#   Size 43: 1 clusters
#   Size 45: 1 clusters
#   Size 46: 3 clusters
#   Size 47: 2 clusters
#   Size 48: 3 clusters
# \n=== FINAL RESULTS (conditional_probability_leiden_params_4) ===
# Mean weighted frequency: 0.098
# Max weighted frequency: 0.125
# Non-zero frequency entries: 2350
# aggregating 16 results for conditional_probability_leiden_params_5
# processing 16 clusterings for 49 outlets (conditional_probability_leiden_params_5)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_leiden_params_5) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 2421.27
# Surprisal weight range: 0.03 to 4.61
# Mean surprisal weight: 0.16
# Median surprisal weight: 0.16
# Cluster size distribution:
#   Size 1: 85 clusters
#   Size 2: 1 clusters
#   Size 39: 1 clusters
#   Size 40: 2 clusters
#   Size 41: 1 clusters
#   Size 42: 1 clusters
#   Size 43: 2 clusters
#   Size 44: 3 clusters
#   Size 45: 1 clusters
#   Size 46: 4 clusters
#   Size 48: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_leiden_params_5) ===
# Mean weighted frequency: 0.134
# Max weighted frequency: 0.309
# Non-zero frequency entries: 2256
# aggregating 16 results for conditional_probability_louvain_params_0
# processing 16 clusterings for 49 outlets (conditional_probability_louvain_params_0)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_louvain_params_0) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 5610.90
# Surprisal weight range: 0.06 to 4.61
# Mean surprisal weight: 0.59
# Median surprisal weight: 0.49
# Cluster size distribution:
#   Size 1: 85 clusters
#   Size 2: 11 clusters
#   Size 3: 3 clusters
#   Size 4: 4 clusters
#   Size 5: 2 clusters
#   Size 6: 2 clusters
#   Size 7: 3 clusters
#   Size 8: 2 clusters
#   Size 10: 1 clusters
#   Size 11: 1 clusters
#   Size 13: 1 clusters
#   Size 15: 1 clusters
#   Size 19: 1 clusters
#   Size 20: 2 clusters
#   Size 22: 1 clusters
#   Size 29: 1 clusters
#   Size 30: 1 clusters
#   Size 31: 1 clusters
#   Size 33: 1 clusters
#   Size 34: 2 clusters
#   Size 35: 3 clusters
#   Size 37: 1 clusters
#   Size 40: 1 clusters
#   Size 43: 1 clusters
#   Size 47: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_louvain_params_0) ===
# Mean weighted frequency: 0.299
# Max weighted frequency: 1.939
# Non-zero frequency entries: 2342
# aggregating 16 results for conditional_probability_louvain_params_1
# processing 16 clusterings for 49 outlets (conditional_probability_louvain_params_1)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_louvain_params_1) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 5870.25
# Surprisal weight range: 0.26 to 4.61
# Mean surprisal weight: 0.70
# Median surprisal weight: 0.53
# Cluster size distribution:
#   Size 1: 94 clusters
#   Size 2: 15 clusters
#   Size 3: 4 clusters
#   Size 4: 6 clusters
#   Size 5: 2 clusters
#   Size 6: 2 clusters
#   Size 7: 3 clusters
#   Size 8: 2 clusters
#   Size 9: 2 clusters
#   Size 10: 1 clusters
#   Size 11: 1 clusters
#   Size 12: 1 clusters
#   Size 16: 1 clusters
#   Size 20: 1 clusters
#   Size 22: 2 clusters
#   Size 27: 2 clusters
#   Size 28: 2 clusters
#   Size 31: 1 clusters
#   Size 32: 2 clusters
#   Size 34: 1 clusters
#   Size 37: 1 clusters
#   Size 38: 1 clusters
#   Size 39: 1 clusters
#   Size 40: 1 clusters
#   Size 41: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_louvain_params_1) ===
# Mean weighted frequency: 0.327
# Max weighted frequency: 2.094
# Non-zero frequency entries: 2246
# aggregating 16 results for conditional_probability_louvain_params_2
# processing 16 clusterings for 49 outlets (conditional_probability_louvain_params_2)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_louvain_params_2) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 6927.54
# Surprisal weight range: 0.44 to 4.61
# Mean surprisal weight: 1.25
# Median surprisal weight: 1.03
# Cluster size distribution:
#   Size 1: 94 clusters
#   Size 2: 16 clusters
#   Size 3: 8 clusters
#   Size 4: 5 clusters
#   Size 5: 3 clusters
#   Size 6: 1 clusters
#   Size 7: 3 clusters
#   Size 8: 7 clusters
#   Size 9: 2 clusters
#   Size 10: 1 clusters
#   Size 11: 2 clusters
#   Size 12: 2 clusters
#   Size 13: 1 clusters
#   Size 14: 4 clusters
#   Size 15: 1 clusters
#   Size 16: 3 clusters
#   Size 23: 2 clusters
#   Size 24: 4 clusters
#   Size 25: 1 clusters
#   Size 26: 1 clusters
#   Size 27: 3 clusters
#   Size 36: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_louvain_params_2) ===
# Mean weighted frequency: 0.422
# Max weighted frequency: 2.131
# Non-zero frequency entries: 2050
# aggregating 16 results for conditional_probability_louvain_params_3
# processing 16 clusterings for 49 outlets (conditional_probability_louvain_params_3)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_louvain_params_3) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7961.13
# Surprisal weight range: 0.71 to 4.61
# Mean surprisal weight: 1.43
# Median surprisal weight: 1.29
# Cluster size distribution:
#   Size 1: 55 clusters
#   Size 2: 3 clusters
#   Size 3: 7 clusters
#   Size 4: 3 clusters
#   Size 5: 3 clusters
#   Size 6: 4 clusters
#   Size 7: 6 clusters
#   Size 8: 3 clusters
#   Size 10: 1 clusters
#   Size 11: 1 clusters
#   Size 13: 2 clusters
#   Size 14: 4 clusters
#   Size 15: 3 clusters
#   Size 16: 4 clusters
#   Size 17: 5 clusters
#   Size 18: 1 clusters
#   Size 20: 4 clusters
#   Size 21: 3 clusters
#   Size 22: 1 clusters
#   Size 23: 1 clusters
#   Size 24: 1 clusters
#   Size 28: 1 clusters
#   Size 30: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_louvain_params_3) ===
# Mean weighted frequency: 0.622
# Max weighted frequency: 2.657
# Non-zero frequency entries: 1600
# aggregating 16 results for conditional_probability_louvain_params_4
# processing 16 clusterings for 49 outlets (conditional_probability_louvain_params_4)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_louvain_params_4) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 8279.10
# Surprisal weight range: 1.03 to 4.03
# Mean surprisal weight: 1.65
# Median surprisal weight: 1.61
# Cluster size distribution:
#   Size 1: 46 clusters
#   Size 3: 2 clusters
#   Size 4: 1 clusters
#   Size 5: 2 clusters
#   Size 6: 2 clusters
#   Size 7: 6 clusters
#   Size 8: 5 clusters
#   Size 9: 1 clusters
#   Size 10: 4 clusters
#   Size 11: 2 clusters
#   Size 12: 1 clusters
#   Size 13: 4 clusters
#   Size 14: 6 clusters
#   Size 15: 7 clusters
#   Size 16: 4 clusters
#   Size 17: 3 clusters
#   Size 18: 3 clusters
#   Size 20: 2 clusters
#   Size 21: 1 clusters
#   Size 23: 2 clusters
#   Size 24: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_louvain_params_4) ===
# Mean weighted frequency: 0.725
# Max weighted frequency: 2.363
# Non-zero frequency entries: 1428
# aggregating 16 results for conditional_probability_louvain_params_5
# processing 16 clusterings for 49 outlets (conditional_probability_louvain_params_5)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_louvain_params_5) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7458.78
# Surprisal weight range: 1.44 to 4.61
# Mean surprisal weight: 2.04
# Median surprisal weight: 1.91
# Cluster size distribution:
#   Size 1: 51 clusters
#   Size 2: 2 clusters
#   Size 3: 5 clusters
#   Size 4: 7 clusters
#   Size 5: 8 clusters
#   Size 6: 7 clusters
#   Size 7: 4 clusters
#   Size 8: 5 clusters
#   Size 9: 6 clusters
#   Size 10: 4 clusters
#   Size 11: 5 clusters
#   Size 12: 5 clusters
#   Size 13: 8 clusters
#   Size 14: 8 clusters
#   Size 15: 3 clusters
#   Size 16: 3 clusters
#   Size 18: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_louvain_params_5) ===
# Mean weighted frequency: 0.825
# Max weighted frequency: 2.905
# Non-zero frequency entries: 1130
# aggregating 16 results for conditional_probability_louvain_params_6
# processing 16 clusterings for 49 outlets (conditional_probability_louvain_params_6)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_louvain_params_6) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 5416.67
# Surprisal weight range: 1.91 to 4.61
# Mean surprisal weight: 2.73
# Median surprisal weight: 2.61
# Cluster size distribution:
#   Size 1: 61 clusters
#   Size 2: 16 clusters
#   Size 3: 25 clusters
#   Size 4: 22 clusters
#   Size 5: 20 clusters
#   Size 6: 21 clusters
#   Size 7: 11 clusters
#   Size 8: 6 clusters
#   Size 9: 5 clusters
#   Size 10: 5 clusters
#   Size 11: 3 clusters
#   Size 12: 3 clusters
#   Size 13: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_louvain_params_6) ===
# Mean weighted frequency: 0.762
# Max weighted frequency: 3.121
# Non-zero frequency entries: 888
# aggregating 16 results for conditional_probability_louvain_params_7
# processing 16 clusterings for 49 outlets (conditional_probability_louvain_params_7)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_louvain_params_7) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 3273.02
# Surprisal weight range: 2.61 to 4.61
# Mean surprisal weight: 3.45
# Median surprisal weight: 3.29
# Cluster size distribution:
#   Size 1: 110 clusters
#   Size 2: 87 clusters
#   Size 3: 64 clusters
#   Size 4: 28 clusters
#   Size 5: 15 clusters
#   Size 6: 9 clusters
#   Size 7: 5 clusters
#   Size 8: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_louvain_params_7) ===
# Mean weighted frequency: 0.802
# Max weighted frequency: 3.530
# Non-zero frequency entries: 510
# aggregating 16 results for conditional_probability_louvain_params_8
# processing 16 clusterings for 49 outlets (conditional_probability_louvain_params_8)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_louvain_params_8) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 2191.38
# Surprisal weight range: 2.81 to 4.61
# Mean surprisal weight: 3.74
# Median surprisal weight: 3.61
# Cluster size distribution:
#   Size 1: 222 clusters
#   Size 2: 140 clusters
#   Size 3: 37 clusters
#   Size 4: 19 clusters
#   Size 5: 8 clusters
#   Size 6: 8 clusters
#   Size 7: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_louvain_params_8) ===
# Mean weighted frequency: 0.783
# Max weighted frequency: 3.608
# Non-zero frequency entries: 350
# aggregating 16 results for conditional_probability_spectral_clustering_params_0
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_0)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_0) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 6266.64
# Surprisal weight range: 0.03 to 2.29
# Mean surprisal weight: 0.52
# Median surprisal weight: 0.41
# Cluster size distribution:
#   Size 1: 1 clusters
#   Size 10: 4 clusters
#   Size 11: 1 clusters
#   Size 12: 3 clusters
#   Size 13: 1 clusters
#   Size 14: 2 clusters
#   Size 15: 3 clusters
#   Size 16: 1 clusters
#   Size 33: 1 clusters
#   Size 34: 3 clusters
#   Size 35: 2 clusters
#   Size 36: 1 clusters
#   Size 37: 3 clusters
#   Size 38: 1 clusters
#   Size 39: 4 clusters
#   Size 48: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_0) ===
# Mean weighted frequency: 0.335
# Max weighted frequency: 1.857
# Non-zero frequency entries: 2336
# aggregating 16 results for conditional_probability_spectral_clustering_params_1
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_1)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_1) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7912.24
# Surprisal weight range: 0.41 to 4.03
# Mean surprisal weight: 0.91
# Median surprisal weight: 0.71
# Cluster size distribution:
#   Size 1: 1 clusters
#   Size 3: 2 clusters
#   Size 4: 1 clusters
#   Size 5: 2 clusters
#   Size 6: 6 clusters
#   Size 7: 1 clusters
#   Size 9: 2 clusters
#   Size 10: 1 clusters
#   Size 11: 3 clusters
#   Size 12: 3 clusters
#   Size 13: 4 clusters
#   Size 14: 2 clusters
#   Size 15: 3 clusters
#   Size 20: 2 clusters
#   Size 23: 1 clusters
#   Size 27: 1 clusters
#   Size 28: 3 clusters
#   Size 30: 3 clusters
#   Size 31: 2 clusters
#   Size 32: 2 clusters
#   Size 34: 1 clusters
#   Size 37: 2 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_1) ===
# Mean weighted frequency: 0.490
# Max weighted frequency: 2.509
# Non-zero frequency entries: 2020
# aggregating 16 results for conditional_probability_spectral_clustering_params_10
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_10)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_10) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7039.87
# Surprisal weight range: 1.16 to 4.61
# Mean surprisal weight: 1.91
# Median surprisal weight: 1.61
# Cluster size distribution:
#   Size 1: 22 clusters
#   Size 2: 9 clusters
#   Size 3: 17 clusters
#   Size 4: 8 clusters
#   Size 5: 18 clusters
#   Size 6: 17 clusters
#   Size 7: 4 clusters
#   Size 8: 6 clusters
#   Size 9: 2 clusters
#   Size 10: 6 clusters
#   Size 11: 1 clusters
#   Size 13: 4 clusters
#   Size 14: 1 clusters
#   Size 15: 1 clusters
#   Size 16: 2 clusters
#   Size 17: 3 clusters
#   Size 18: 2 clusters
#   Size 20: 2 clusters
#   Size 21: 2 clusters
#   Size 22: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_10) ===
# Mean weighted frequency: 0.521
# Max weighted frequency: 3.258
# Non-zero frequency entries: 1690
# aggregating 16 results for conditional_probability_spectral_clustering_params_11
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_11)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_11) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 6684.45
# Surprisal weight range: 0.57 to 4.61
# Mean surprisal weight: 1.67
# Median surprisal weight: 1.53
# Cluster size distribution:
#   Size 1: 71 clusters
#   Size 2: 4 clusters
#   Size 3: 14 clusters
#   Size 4: 8 clusters
#   Size 5: 9 clusters
#   Size 6: 12 clusters
#   Size 7: 8 clusters
#   Size 8: 7 clusters
#   Size 9: 3 clusters
#   Size 10: 1 clusters
#   Size 11: 6 clusters
#   Size 12: 4 clusters
#   Size 13: 1 clusters
#   Size 14: 1 clusters
#   Size 15: 3 clusters
#   Size 17: 2 clusters
#   Size 18: 1 clusters
#   Size 20: 1 clusters
#   Size 21: 1 clusters
#   Size 24: 1 clusters
#   Size 29: 1 clusters
#   Size 33: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_11) ===
# Mean weighted frequency: 0.487
# Max weighted frequency: 3.011
# Non-zero frequency entries: 1714
# aggregating 16 results for conditional_probability_spectral_clustering_params_12
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_12)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_12) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 8825.24
# Surprisal weight range: 0.57 to 4.61
# Mean surprisal weight: 1.21
# Median surprisal weight: 1.03
# Cluster size distribution:
#   Size 1: 1 clusters
#   Size 2: 1 clusters
#   Size 6: 1 clusters
#   Size 7: 2 clusters
#   Size 9: 2 clusters
#   Size 10: 2 clusters
#   Size 11: 3 clusters
#   Size 12: 1 clusters
#   Size 13: 5 clusters
#   Size 14: 7 clusters
#   Size 15: 3 clusters
#   Size 16: 2 clusters
#   Size 17: 2 clusters
#   Size 19: 1 clusters
#   Size 22: 4 clusters
#   Size 24: 3 clusters
#   Size 25: 2 clusters
#   Size 26: 1 clusters
#   Size 27: 2 clusters
#   Size 29: 1 clusters
#   Size 33: 2 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_12) ===
# Mean weighted frequency: 0.562
# Max weighted frequency: 1.919
# Non-zero frequency entries: 1964
# aggregating 16 results for conditional_probability_spectral_clustering_params_13
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_13)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_13) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 8126.78
# Surprisal weight range: 1.16 to 4.61
# Mean surprisal weight: 1.98
# Median surprisal weight: 1.91
# Cluster size distribution:
#   Size 2: 1 clusters
#   Size 3: 1 clusters
#   Size 4: 5 clusters
#   Size 5: 5 clusters
#   Size 6: 5 clusters
#   Size 7: 8 clusters
#   Size 8: 7 clusters
#   Size 9: 9 clusters
#   Size 10: 9 clusters
#   Size 11: 7 clusters
#   Size 12: 5 clusters
#   Size 13: 3 clusters
#   Size 14: 3 clusters
#   Size 15: 3 clusters
#   Size 16: 3 clusters
#   Size 17: 3 clusters
#   Size 18: 1 clusters
#   Size 19: 1 clusters
#   Size 22: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_13) ===
# Mean weighted frequency: 0.609
# Max weighted frequency: 2.717
# Non-zero frequency entries: 1668
# aggregating 16 results for conditional_probability_spectral_clustering_params_14
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_14)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_14) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 6440.42
# Surprisal weight range: 1.91 to 4.61
# Mean surprisal weight: 2.64
# Median surprisal weight: 2.61
# Cluster size distribution:
#   Size 1: 3 clusters
#   Size 2: 3 clusters
#   Size 3: 12 clusters
#   Size 4: 16 clusters
#   Size 5: 23 clusters
#   Size 6: 17 clusters
#   Size 7: 15 clusters
#   Size 8: 15 clusters
#   Size 9: 13 clusters
#   Size 10: 2 clusters
#   Size 11: 2 clusters
#   Size 12: 4 clusters
#   Size 13: 2 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_14) ===
# Mean weighted frequency: 0.540
# Max weighted frequency: 3.411
# Non-zero frequency entries: 1490
# aggregating 16 results for conditional_probability_spectral_clustering_params_15
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_15)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_15) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 5419.34
# Surprisal weight range: 2.29 to 4.61
# Mean surprisal weight: 3.02
# Median surprisal weight: 3.03
# Cluster size distribution:
#   Size 1: 3 clusters
#   Size 2: 6 clusters
#   Size 3: 30 clusters
#   Size 4: 37 clusters
#   Size 5: 25 clusters
#   Size 6: 29 clusters
#   Size 7: 13 clusters
#   Size 8: 13 clusters
#   Size 9: 3 clusters
#   Size 10: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_15) ===
# Mean weighted frequency: 0.574
# Max weighted frequency: 3.750
# Non-zero frequency entries: 1180
# aggregating 16 results for conditional_probability_spectral_clustering_params_2
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_2)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_2) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 8134.91
# Surprisal weight range: 0.49 to 4.61
# Mean surprisal weight: 1.22
# Median surprisal weight: 1.09
# Cluster size distribution:
#   Size 1: 2 clusters
#   Size 2: 1 clusters
#   Size 3: 5 clusters
#   Size 4: 2 clusters
#   Size 5: 3 clusters
#   Size 6: 5 clusters
#   Size 7: 2 clusters
#   Size 8: 3 clusters
#   Size 9: 5 clusters
#   Size 10: 5 clusters
#   Size 11: 8 clusters
#   Size 12: 4 clusters
#   Size 13: 1 clusters
#   Size 14: 2 clusters
#   Size 18: 1 clusters
#   Size 21: 3 clusters
#   Size 22: 1 clusters
#   Size 23: 4 clusters
#   Size 25: 1 clusters
#   Size 26: 2 clusters
#   Size 29: 1 clusters
#   Size 32: 1 clusters
#   Size 34: 1 clusters
#   Size 35: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_2) ===
# Mean weighted frequency: 0.519
# Max weighted frequency: 2.792
# Non-zero frequency entries: 1958
# aggregating 16 results for conditional_probability_spectral_clustering_params_3
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_3)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_3) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 8257.56
# Surprisal weight range: 0.81 to 4.61
# Mean surprisal weight: 1.49
# Median surprisal weight: 1.29
# Cluster size distribution:
#   Size 1: 8 clusters
#   Size 2: 4 clusters
#   Size 3: 7 clusters
#   Size 4: 4 clusters
#   Size 5: 6 clusters
#   Size 6: 5 clusters
#   Size 7: 4 clusters
#   Size 8: 5 clusters
#   Size 9: 2 clusters
#   Size 10: 5 clusters
#   Size 11: 4 clusters
#   Size 12: 2 clusters
#   Size 13: 1 clusters
#   Size 14: 1 clusters
#   Size 15: 1 clusters
#   Size 16: 3 clusters
#   Size 17: 1 clusters
#   Size 18: 5 clusters
#   Size 19: 1 clusters
#   Size 20: 1 clusters
#   Size 21: 3 clusters
#   Size 22: 3 clusters
#   Size 23: 1 clusters
#   Size 25: 1 clusters
#   Size 26: 1 clusters
#   Size 28: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_3) ===
# Mean weighted frequency: 0.511
# Max weighted frequency: 3.170
# Non-zero frequency entries: 2018
# aggregating 16 results for conditional_probability_spectral_clustering_params_4
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_4)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_4) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7756.97
# Surprisal weight range: 0.71 to 4.61
# Mean surprisal weight: 1.57
# Median surprisal weight: 1.29
# Cluster size distribution:
#   Size 1: 11 clusters
#   Size 2: 6 clusters
#   Size 3: 10 clusters
#   Size 4: 8 clusters
#   Size 5: 10 clusters
#   Size 6: 6 clusters
#   Size 7: 4 clusters
#   Size 8: 6 clusters
#   Size 9: 5 clusters
#   Size 10: 4 clusters
#   Size 11: 4 clusters
#   Size 12: 3 clusters
#   Size 13: 2 clusters
#   Size 14: 1 clusters
#   Size 15: 1 clusters
#   Size 16: 2 clusters
#   Size 17: 1 clusters
#   Size 19: 1 clusters
#   Size 20: 2 clusters
#   Size 21: 2 clusters
#   Size 22: 3 clusters
#   Size 23: 1 clusters
#   Size 24: 2 clusters
#   Size 30: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_4) ===
# Mean weighted frequency: 0.528
# Max weighted frequency: 3.444
# Non-zero frequency entries: 1836
# aggregating 16 results for conditional_probability_spectral_clustering_params_5
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_5)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_5) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7059.71
# Surprisal weight range: 1.03 to 4.61
# Mean surprisal weight: 1.86
# Median surprisal weight: 1.61
# Cluster size distribution:
#   Size 1: 25 clusters
#   Size 2: 7 clusters
#   Size 3: 17 clusters
#   Size 4: 10 clusters
#   Size 5: 18 clusters
#   Size 6: 8 clusters
#   Size 7: 8 clusters
#   Size 8: 8 clusters
#   Size 9: 5 clusters
#   Size 10: 2 clusters
#   Size 11: 3 clusters
#   Size 12: 1 clusters
#   Size 13: 1 clusters
#   Size 14: 1 clusters
#   Size 15: 2 clusters
#   Size 16: 2 clusters
#   Size 17: 3 clusters
#   Size 18: 1 clusters
#   Size 19: 2 clusters
#   Size 21: 1 clusters
#   Size 22: 1 clusters
#   Size 23: 1 clusters
#   Size 24: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_5) ===
# Mean weighted frequency: 0.500
# Max weighted frequency: 3.460
# Non-zero frequency entries: 1764
# aggregating 16 results for conditional_probability_spectral_clustering_params_6
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_6)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_6) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 6381.63
# Surprisal weight range: 1.03 to 4.61
# Mean surprisal weight: 1.97
# Median surprisal weight: 1.53
# Cluster size distribution:
#   Size 1: 35 clusters
#   Size 2: 23 clusters
#   Size 3: 25 clusters
#   Size 4: 10 clusters
#   Size 5: 19 clusters
#   Size 6: 15 clusters
#   Size 7: 3 clusters
#   Size 8: 10 clusters
#   Size 9: 3 clusters
#   Size 10: 2 clusters
#   Size 12: 3 clusters
#   Size 14: 1 clusters
#   Size 16: 1 clusters
#   Size 17: 2 clusters
#   Size 18: 3 clusters
#   Size 19: 3 clusters
#   Size 20: 1 clusters
#   Size 24: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_6) ===
# Mean weighted frequency: 0.515
# Max weighted frequency: 3.810
# Non-zero frequency entries: 1548
# aggregating 16 results for conditional_probability_spectral_clustering_params_7
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_7)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_7) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 5906.43
# Surprisal weight range: 1.16 to 4.61
# Mean surprisal weight: 2.02
# Median surprisal weight: 1.71
# Cluster size distribution:
#   Size 1: 62 clusters
#   Size 2: 26 clusters
#   Size 3: 26 clusters
#   Size 4: 17 clusters
#   Size 5: 21 clusters
#   Size 6: 15 clusters
#   Size 7: 3 clusters
#   Size 8: 4 clusters
#   Size 9: 1 clusters
#   Size 10: 1 clusters
#   Size 11: 2 clusters
#   Size 12: 1 clusters
#   Size 14: 2 clusters
#   Size 15: 3 clusters
#   Size 16: 1 clusters
#   Size 17: 2 clusters
#   Size 18: 1 clusters
#   Size 19: 2 clusters
#   Size 22: 2 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_7) ===
# Mean weighted frequency: 0.494
# Max weighted frequency: 3.296
# Non-zero frequency entries: 1494
# aggregating 16 results for conditional_probability_spectral_clustering_params_8
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_8)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_8) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7909.83
# Surprisal weight range: 0.41 to 4.03
# Mean surprisal weight: 0.91
# Median surprisal weight: 0.71
# Cluster size distribution:
#   Size 1: 1 clusters
#   Size 3: 2 clusters
#   Size 4: 1 clusters
#   Size 5: 2 clusters
#   Size 6: 6 clusters
#   Size 8: 1 clusters
#   Size 9: 2 clusters
#   Size 10: 1 clusters
#   Size 11: 3 clusters
#   Size 12: 3 clusters
#   Size 13: 4 clusters
#   Size 14: 2 clusters
#   Size 15: 3 clusters
#   Size 16: 1 clusters
#   Size 23: 1 clusters
#   Size 24: 1 clusters
#   Size 27: 2 clusters
#   Size 28: 2 clusters
#   Size 30: 3 clusters
#   Size 31: 2 clusters
#   Size 32: 2 clusters
#   Size 34: 1 clusters
#   Size 37: 2 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_8) ===
# Mean weighted frequency: 0.489
# Max weighted frequency: 2.517
# Non-zero frequency entries: 2020
# aggregating 16 results for conditional_probability_spectral_clustering_params_9
# processing 16 clusterings for 49 outlets (conditional_probability_spectral_clustering_params_9)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_spectral_clustering_params_9) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7782.07
# Surprisal weight range: 0.37 to 4.61
# Mean surprisal weight: 1.29
# Median surprisal weight: 1.03
# Cluster size distribution:
#   Size 1: 8 clusters
#   Size 2: 1 clusters
#   Size 3: 8 clusters
#   Size 4: 5 clusters
#   Size 5: 6 clusters
#   Size 6: 10 clusters
#   Size 7: 2 clusters
#   Size 8: 4 clusters
#   Size 9: 4 clusters
#   Size 10: 6 clusters
#   Size 11: 4 clusters
#   Size 12: 3 clusters
#   Size 13: 2 clusters
#   Size 14: 1 clusters
#   Size 16: 1 clusters
#   Size 17: 1 clusters
#   Size 18: 3 clusters
#   Size 20: 1 clusters
#   Size 22: 2 clusters
#   Size 24: 1 clusters
#   Size 25: 1 clusters
#   Size 26: 1 clusters
#   Size 28: 2 clusters
#   Size 29: 2 clusters
#   Size 38: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_spectral_clustering_params_9) ===
# Mean weighted frequency: 0.464
# Max weighted frequency: 3.330
# Non-zero frequency entries: 2098
# aggregating 13 results for conditional_probability_threshold_components_params_0
# processing 13 clusterings for 49 outlets (conditional_probability_threshold_components_params_0)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_threshold_components_params_0) ===
# Surprisal weighting: enabled
# Total clusterings processed: 13
# Total weight sum: 1358.48
# Surprisal weight range: 0.03 to 0.22
# Mean surprisal weight: 0.10
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 46 clusters
#   Size 42: 2 clusters
#   Size 43: 1 clusters
#   Size 44: 2 clusters
#   Size 46: 4 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_threshold_components_params_0) ===
# Mean weighted frequency: 0.093
# Max weighted frequency: 0.110
# Non-zero frequency entries: 2256
# aggregating 13 results for conditional_probability_threshold_components_params_1
# processing 13 clusterings for 49 outlets (conditional_probability_threshold_components_params_1)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_threshold_components_params_1) ===
# Surprisal weighting: enabled
# Total clusterings processed: 13
# Total weight sum: 1358.48
# Surprisal weight range: 0.03 to 0.22
# Mean surprisal weight: 0.10
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 46 clusters
#   Size 42: 2 clusters
#   Size 43: 1 clusters
#   Size 44: 2 clusters
#   Size 46: 4 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_threshold_components_params_1) ===
# Mean weighted frequency: 0.093
# Max weighted frequency: 0.110
# Non-zero frequency entries: 2256
# aggregating 14 results for conditional_probability_threshold_components_params_2
# processing 14 clusterings for 49 outlets (conditional_probability_threshold_components_params_2)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_threshold_components_params_2) ===
# Surprisal weighting: enabled
# Total clusterings processed: 14
# Total weight sum: 1446.75
# Surprisal weight range: 0.03 to 0.22
# Mean surprisal weight: 0.10
# Median surprisal weight: 0.09
# Cluster size distribution:
#   Size 1: 49 clusters
#   Size 42: 2 clusters
#   Size 43: 2 clusters
#   Size 44: 1 clusters
#   Size 46: 4 clusters
#   Size 47: 1 clusters
#   Size 48: 4 clusters
# \n=== FINAL RESULTS (conditional_probability_threshold_components_params_2) ===
# Mean weighted frequency: 0.088
# Max weighted frequency: 0.109
# Non-zero frequency entries: 2350
# aggregating 16 results for conditional_probability_threshold_components_params_3
# processing 16 clusterings for 49 outlets (conditional_probability_threshold_components_params_3)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_threshold_components_params_3) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 4288.44
# Surprisal weight range: 0.19 to 4.61
# Mean surprisal weight: 0.40
# Median surprisal weight: 0.37
# Cluster size distribution:
#   Size 1: 153 clusters
#   Size 2: 8 clusters
#   Size 3: 6 clusters
#   Size 4: 2 clusters
#   Size 31: 2 clusters
#   Size 32: 2 clusters
#   Size 33: 1 clusters
#   Size 35: 1 clusters
#   Size 36: 1 clusters
#   Size 37: 1 clusters
#   Size 38: 2 clusters
#   Size 39: 1 clusters
#   Size 40: 1 clusters
#   Size 41: 2 clusters
#   Size 42: 1 clusters
#   Size 43: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_threshold_components_params_3) ===
# Mean weighted frequency: 0.230
# Max weighted frequency: 1.893
# Non-zero frequency entries: 2330
# aggregating 16 results for conditional_probability_threshold_components_params_4
# processing 16 clusterings for 49 outlets (conditional_probability_threshold_components_params_4)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_threshold_components_params_4) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 2677.11
# Surprisal weight range: 1.37 to 4.61
# Mean surprisal weight: 1.83
# Median surprisal weight: 1.71
# Cluster size distribution:
#   Size 1: 510 clusters
#   Size 2: 14 clusters
#   Size 3: 4 clusters
#   Size 4: 3 clusters
#   Size 5: 1 clusters
#   Size 6: 1 clusters
#   Size 7: 2 clusters
#   Size 8: 2 clusters
#   Size 11: 1 clusters
#   Size 13: 1 clusters
#   Size 14: 2 clusters
#   Size 15: 4 clusters
#   Size 16: 2 clusters
#   Size 18: 1 clusters
#   Size 19: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_threshold_components_params_4) ===
# Mean weighted frequency: 0.504
# Max weighted frequency: 1.976
# Non-zero frequency entries: 664
# aggregating 16 results for conditional_probability_walktrap_params_0
# processing 16 clusterings for 49 outlets (conditional_probability_walktrap_params_0)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_walktrap_params_0) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7778.50
# Surprisal weight range: 0.57 to 4.03
# Mean surprisal weight: 1.08
# Median surprisal weight: 0.71
# Cluster size distribution:
#   Size 1: 51 clusters
#   Size 3: 3 clusters
#   Size 4: 1 clusters
#   Size 5: 1 clusters
#   Size 6: 1 clusters
#   Size 7: 2 clusters
#   Size 8: 3 clusters
#   Size 9: 1 clusters
#   Size 10: 1 clusters
#   Size 11: 2 clusters
#   Size 12: 3 clusters
#   Size 13: 6 clusters
#   Size 14: 4 clusters
#   Size 16: 6 clusters
#   Size 19: 2 clusters
#   Size 20: 1 clusters
#   Size 25: 1 clusters
#   Size 30: 3 clusters
#   Size 31: 2 clusters
#   Size 32: 3 clusters
#   Size 33: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_walktrap_params_0) ===
# Mean weighted frequency: 0.517
# Max weighted frequency: 2.111
# Non-zero frequency entries: 1880
# aggregating 16 results for conditional_probability_walktrap_params_1
# processing 16 clusterings for 49 outlets (conditional_probability_walktrap_params_1)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_walktrap_params_1) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7901.23
# Surprisal weight range: 0.61 to 4.03
# Mean surprisal weight: 1.03
# Median surprisal weight: 0.81
# Cluster size distribution:
#   Size 1: 52 clusters
#   Size 3: 2 clusters
#   Size 6: 2 clusters
#   Size 7: 1 clusters
#   Size 8: 3 clusters
#   Size 10: 2 clusters
#   Size 12: 2 clusters
#   Size 13: 5 clusters
#   Size 14: 3 clusters
#   Size 15: 2 clusters
#   Size 16: 2 clusters
#   Size 17: 2 clusters
#   Size 19: 2 clusters
#   Size 20: 1 clusters
#   Size 21: 1 clusters
#   Size 26: 1 clusters
#   Size 27: 1 clusters
#   Size 28: 2 clusters
#   Size 30: 3 clusters
#   Size 31: 2 clusters
#   Size 32: 3 clusters
# \n=== FINAL RESULTS (conditional_probability_walktrap_params_1) ===
# Mean weighted frequency: 0.541
# Max weighted frequency: 2.081
# Non-zero frequency entries: 1824
# aggregating 16 results for conditional_probability_walktrap_params_2
# processing 16 clusterings for 49 outlets (conditional_probability_walktrap_params_2)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_walktrap_params_2) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7852.52
# Surprisal weight range: 0.57 to 4.03
# Mean surprisal weight: 1.00
# Median surprisal weight: 0.71
# Cluster size distribution:
#   Size 1: 49 clusters
#   Size 3: 2 clusters
#   Size 5: 1 clusters
#   Size 6: 2 clusters
#   Size 7: 1 clusters
#   Size 8: 5 clusters
#   Size 10: 1 clusters
#   Size 13: 6 clusters
#   Size 14: 1 clusters
#   Size 15: 2 clusters
#   Size 16: 2 clusters
#   Size 17: 1 clusters
#   Size 18: 1 clusters
#   Size 21: 4 clusters
#   Size 22: 1 clusters
#   Size 25: 1 clusters
#   Size 26: 1 clusters
#   Size 28: 1 clusters
#   Size 30: 3 clusters
#   Size 31: 2 clusters
#   Size 32: 3 clusters
#   Size 33: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_walktrap_params_2) ===
# Mean weighted frequency: 0.536
# Max weighted frequency: 2.109
# Non-zero frequency entries: 1830
# aggregating 16 results for conditional_probability_walktrap_params_3
# processing 16 clusterings for 49 outlets (conditional_probability_walktrap_params_3)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_walktrap_params_3) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7864.27
# Surprisal weight range: 0.57 to 4.61
# Mean surprisal weight: 0.97
# Median surprisal weight: 0.71
# Cluster size distribution:
#   Size 1: 48 clusters
#   Size 2: 1 clusters
#   Size 3: 2 clusters
#   Size 5: 1 clusters
#   Size 6: 1 clusters
#   Size 7: 1 clusters
#   Size 8: 4 clusters
#   Size 12: 1 clusters
#   Size 13: 4 clusters
#   Size 14: 1 clusters
#   Size 15: 2 clusters
#   Size 16: 4 clusters
#   Size 17: 2 clusters
#   Size 19: 1 clusters
#   Size 20: 1 clusters
#   Size 21: 2 clusters
#   Size 27: 2 clusters
#   Size 28: 2 clusters
#   Size 30: 3 clusters
#   Size 31: 2 clusters
#   Size 32: 3 clusters
#   Size 33: 1 clusters
# \n=== FINAL RESULTS (conditional_probability_walktrap_params_3) ===
# Mean weighted frequency: 0.549
# Max weighted frequency: 1.986
# Non-zero frequency entries: 1790
# aggregating 16 results for conditional_probability_walktrap_params_4
# processing 16 clusterings for 49 outlets (conditional_probability_walktrap_params_4)
# \n=== SURPRISAL WEIGHTING DIAGNOSTICS (conditional_probability_walktrap_params_4) ===
# Surprisal weighting: enabled
# Total clusterings processed: 16
# Total weight sum: 7846.90
# Surprisal weight range: 0.57 to 4.03
# Mean surprisal weight: 0.95
# Median surprisal weight: 0.71
# Cluster size distribution:
#   Size 1: 48 clusters
#   Size 3: 1 clusters
#   Size 5: 1 clusters
#   Size 6: 1 clusters
#   Size 7: 1 clusters
#   Size 8: 3 clusters
#   Size 9: 2 clusters
# ...
# tfidf_similarity_walktrap_params_8                                                -0.020
#
#                                                 conditional_probability_label_propagation_params_0  \
# conditional_probability_girvan_newman_params_0                                              0.913
# conditional_probability_k_cores_params_0                                                   -0.022
# conditional_probability_k_cores_params_1                                                   -0.022
# conditional_probability_k_cores_params_2                                                   -0.026
# conditional_probability_k_cores_params_3                                                   -0.029
# ...                                                                                           ...
# tfidf_similarity_walktrap_params_4                                                          0.249
# tfidf_similarity_walktrap_params_5                                                          0.257
# tfidf_similarity_walktrap_params_6                                                          0.703
# tfidf_similarity_walktrap_params_7                                                          0.599
# tfidf_similarity_walktrap_params_8                                                          0.570
#
#                                                 conditional_probability_leiden_params_0  \
# conditional_probability_girvan_newman_params_0                                    0.453
# conditional_probability_k_cores_params_0                                         -0.033
# conditional_probability_k_cores_params_1                                         -0.033
# conditional_probability_k_cores_params_2                                         -0.034
# conditional_probability_k_cores_params_3                                         -0.035
# ...                                                                                 ...
# tfidf_similarity_walktrap_params_4                                                0.352
# tfidf_similarity_walktrap_params_5                                                0.354
# tfidf_similarity_walktrap_params_6                                                0.415
# tfidf_similarity_walktrap_params_7                                                0.484
# tfidf_similarity_walktrap_params_8                                                0.479
#
#                                                 conditional_probability_leiden_params_1  \
# conditional_probability_girvan_newman_params_0                                    0.913
# conditional_probability_k_cores_params_0                                         -0.022
# conditional_probability_k_cores_params_1                                         -0.022
# conditional_probability_k_cores_params_2                                         -0.026
# conditional_probability_k_cores_params_3                                         -0.029
# ...                                                                                 ...
# tfidf_similarity_walktrap_params_4                                                0.249
# tfidf_similarity_walktrap_params_5                                                0.257
# tfidf_similarity_walktrap_params_6                                                0.703
# tfidf_similarity_walktrap_params_7                                                0.599
# tfidf_similarity_walktrap_params_8                                                0.570
#
#                                                 conditional_probability_leiden_params_2  \
# conditional_probability_girvan_newman_params_0                                    0.941
# conditional_probability_k_cores_params_0                                         -0.016
# conditional_probability_k_cores_params_1                                         -0.014
# conditional_probability_k_cores_params_2                                         -0.017
# conditional_probability_k_cores_params_3                                         -0.019
# ...                                                                                 ...
# tfidf_similarity_walktrap_params_4                                                0.249
# tfidf_similarity_walktrap_params_5                                                0.257
# tfidf_similarity_walktrap_params_6                                                0.721
# tfidf_similarity_walktrap_params_7                                                0.621
# tfidf_similarity_walktrap_params_8                                                0.589
#
#                                                 ...  \
# conditional_probability_girvan_newman_params_0  ...
# conditional_probability_k_cores_params_0        ...
# conditional_probability_k_cores_params_1        ...
# conditional_probability_k_cores_params_2        ...
# conditional_probability_k_cores_params_3        ...
# ...                                             ...
# tfidf_similarity_walktrap_params_4              ...
# tfidf_similarity_walktrap_params_5              ...
# tfidf_similarity_walktrap_params_6              ...
# tfidf_similarity_walktrap_params_7              ...
# tfidf_similarity_walktrap_params_8              ...
#
#                                                 tfidf_similarity_threshold_components_params_4  \
# conditional_probability_girvan_newman_params_0                                          -0.013
# conditional_probability_k_cores_params_0                                                -0.010
# conditional_probability_k_cores_params_1                                                -0.010
# conditional_probability_k_cores_params_2                                                -0.010
# conditional_probability_k_cores_params_3                                                -0.010
# ...                                                                                        ...
# tfidf_similarity_walktrap_params_4                                                       0.124
# tfidf_similarity_walktrap_params_5                                                       0.121
# tfidf_similarity_walktrap_params_6                                                      -0.004
# tfidf_similarity_walktrap_params_7                                                       0.019
# tfidf_similarity_walktrap_params_8                                                       0.085
#
#                                                 tfidf_similarity_walktrap_params_0  \
# conditional_probability_girvan_newman_params_0                               0.249
# conditional_probability_k_cores_params_0                                    -0.019
# conditional_probability_k_cores_params_1                                    -0.018
# conditional_probability_k_cores_params_2                                    -0.019
# conditional_probability_k_cores_params_3                                    -0.019
# ...                                                                            ...
# tfidf_similarity_walktrap_params_4                                           0.917
# tfidf_similarity_walktrap_params_5                                           0.884
# tfidf_similarity_walktrap_params_6                                           0.200
# tfidf_similarity_walktrap_params_7                                           0.253
# tfidf_similarity_walktrap_params_8                                           0.270
#
#                                                 tfidf_similarity_walktrap_params_1  \
# conditional_probability_girvan_newman_params_0                               0.239
# conditional_probability_k_cores_params_0                                    -0.018
# conditional_probability_k_cores_params_1                                    -0.017
# conditional_probability_k_cores_params_2                                    -0.019
# conditional_probability_k_cores_params_3                                    -0.019
# ...                                                                            ...
# tfidf_similarity_walktrap_params_4                                           0.965
# tfidf_similarity_walktrap_params_5                                           0.936
# tfidf_similarity_walktrap_params_6                                           0.190
# tfidf_similarity_walktrap_params_7                                           0.236
# tfidf_similarity_walktrap_params_8                                           0.251
#
#                                                 tfidf_similarity_walktrap_params_2  \
# conditional_probability_girvan_newman_params_0                               0.237
# conditional_probability_k_cores_params_0                                    -0.015
# conditional_probability_k_cores_params_1                                    -0.015
# conditional_probability_k_cores_params_2                                    -0.016
# conditional_probability_k_cores_params_3                                    -0.017
# ...                                                                            ...
# tfidf_similarity_walktrap_params_4                                           0.982
# tfidf_similarity_walktrap_params_5                                           0.943
# tfidf_similarity_walktrap_params_6                                           0.189
# tfidf_similarity_walktrap_params_7                                           0.236
# tfidf_similarity_walktrap_params_8                                           0.256
#
#                                                 tfidf_similarity_walktrap_params_3  \
# conditional_probability_girvan_newman_params_0                               0.224
# conditional_probability_k_cores_params_0                                    -0.017
# conditional_probability_k_cores_params_1                                    -0.017
# conditional_probability_k_cores_params_2                                    -0.018
# conditional_probability_k_cores_params_3                                    -0.019
# ...                                                                            ...
# tfidf_similarity_walktrap_params_4                                           0.985
# tfidf_similarity_walktrap_params_5                                           0.944
# tfidf_similarity_walktrap_params_6                                           0.188
# tfidf_similarity_walktrap_params_7                                           0.234
# tfidf_similarity_walktrap_params_8                                           0.253
#
#                                                 tfidf_similarity_walktrap_params_4  \
# conditional_probability_girvan_newman_params_0                               0.231
# conditional_probability_k_cores_params_0                                    -0.017
# conditional_probability_k_cores_params_1                                    -0.017
# conditional_probability_k_cores_params_2                                    -0.018
# conditional_probability_k_cores_params_3                                    -0.019
# ...                                                                            ...
# tfidf_similarity_walktrap_params_4                                           1.000
# tfidf_similarity_walktrap_params_5                                           0.967
# tfidf_similarity_walktrap_params_6                                           0.184
# tfidf_similarity_walktrap_params_7                                           0.228
# tfidf_similarity_walktrap_params_8                                           0.245
#
#                                                 tfidf_similarity_walktrap_params_5  \
# conditional_probability_girvan_newman_params_0                               0.239
# conditional_probability_k_cores_params_0                                    -0.018
# conditional_probability_k_cores_params_1                                    -0.018
# conditional_probability_k_cores_params_2                                    -0.019
# conditional_probability_k_cores_params_3                                    -0.020
# ...                                                                            ...
# tfidf_similarity_walktrap_params_4                                           0.967
# tfidf_similarity_walktrap_params_5                                           1.000
# tfidf_similarity_walktrap_params_6                                           0.189
# tfidf_similarity_walktrap_params_7                                           0.229
# tfidf_similarity_walktrap_params_8                                           0.242
#
#                                                 tfidf_similarity_walktrap_params_6  \
# conditional_probability_girvan_newman_params_0                               0.742
# conditional_probability_k_cores_params_0                                    -0.016
# conditional_probability_k_cores_params_1                                    -0.014
# conditional_probability_k_cores_params_2                                    -0.015
# conditional_probability_k_cores_params_3                                    -0.016
# ...                                                                            ...
# tfidf_similarity_walktrap_params_4                                           0.184
# tfidf_similarity_walktrap_params_5                                           0.189
# tfidf_similarity_walktrap_params_6                                           1.000
# tfidf_similarity_walktrap_params_7                                           0.885
# tfidf_similarity_walktrap_params_8                                           0.832
#
#                                                 tfidf_similarity_walktrap_params_7  \
# conditional_probability_girvan_newman_params_0                               0.668
# conditional_probability_k_cores_params_0                                    -0.024
# conditional_probability_k_cores_params_1                                    -0.023
# conditional_probability_k_cores_params_2                                    -0.025
# conditional_probability_k_cores_params_3                                    -0.025
# ...                                                                            ...
# tfidf_similarity_walktrap_params_4                                           0.228
# tfidf_similarity_walktrap_params_5                                           0.229
# tfidf_similarity_walktrap_params_6                                           0.885
# tfidf_similarity_walktrap_params_7                                           1.000
# tfidf_similarity_walktrap_params_8                                           0.935
#
#                                                 tfidf_similarity_walktrap_params_8
# conditional_probability_girvan_newman_params_0                               0.629
# conditional_probability_k_cores_params_0                                    -0.023
# conditional_probability_k_cores_params_1                                    -0.023
# conditional_probability_k_cores_params_2                                    -0.027
# conditional_probability_k_cores_params_3                                    -0.027
# ...                                                                            ...
# tfidf_similarity_walktrap_params_4                                           0.245
# tfidf_similarity_walktrap_params_5                                           0.242
# tfidf_similarity_walktrap_params_6                                           0.832
# tfidf_similarity_walktrap_params_7                                           0.935
# tfidf_similarity_walktrap_params_8                                           1.000
#
# [405 rows x 405 columns]
# \nmost similar methods: conditional_probability_k_cores_params_1 ↔ cooccurrence_k_cores_params_4 (r = 0.970)
# most different methods: correlation_louvain_params_1 ↔ dice_leiden_params_4 (r = -0.061)

# %%
# %%

# =============================================================================
# 9. FULL GRID SIZE & RETENTION RATE
# =============================================================================

# calculate size of full parameter grid evaluated and retention fraction after exclusions
all_results = analyzer.get_results()
if not all_results.empty:
    n_windows_total = temporal_summary['n_windows'] if 'n_windows' in temporal_summary else all_results['sample_id'].nunique()
    n_network_methods = all_results['network_method'].nunique()
    n_community_methods = all_results['community_method'].nunique()
    n_param_ids = all_results['param_id'].nunique()
    full_grid_size = n_windows_total * n_network_methods * n_community_methods * n_param_ids
    retained_results = len(all_results)
    retention_pct = 100.0 * retained_results / full_grid_size if full_grid_size else 0.0
    print(f"\n=== PARAMETER GRID SUMMARY ===")
    print(f"Windows (S): {n_windows_total}")
    print(f"Network methods (M): {n_network_methods}")
    print(f"Community methods (C): {n_community_methods}")
    print(f"Hyper-parameter configs (H): {n_param_ids}")
    print(f"Full grid size: {full_grid_size}")
    print(f"Retained results after filtering: {retained_results} ({retention_pct:.1f}%)")
# Out:
# === PARAMETER GRID SUMMARY ===
# Windows (S): 16
# Network methods (M): 9
# Community methods (C): 10
# Hyper-parameter configs (H): 16
# Full grid size: 23040
# Retained results after filtering: 6191 (26.9%)
